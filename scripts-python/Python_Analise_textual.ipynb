# %%
import pandas as pd
import nltk
import itertools
from nltk.corpus import stopwords
from gensim import corpora, models
from nltk.stem import PorterStemmer
from nltk.stem import LancasterStemmer

# %%
import nltk
#nltk.download('punkt')
#nltk.download('wordnet')
from nltk import sent_tokenize, word_tokenize
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import stopwords
import pandas as pd
import numpy as np
import re

# %%
base = pd.read_csv("baselimpa.csv")

# %%
pd.options.display.max_colwidth = 100

base[base['tweet'].str.contains("escola")]['tweet']
# Out:
# 7                  estudantes da escola municipal do complexo da maré agachados sob ataque do caveirão aéreo
# 10       #repost @bertjoi with get_repost ・・・ agatha. 8 anos. tiro nas costas. estava dentro da kombi/lot...
# 12       #witzelassassino.  parem de nos matar!  abaixo criançasda escolamunicipal no pinheiro, complexo ...
# 13       nas escolas que foram alvos do caveirão aéreo, funcionários ainda estão com medo. a maioria se m...
# 17       nós, moradores minimamente alertamos em dias de operações policiais: atividade morador, não leve...
# 30       nova escola, por @leandrobeguoci | com 'caveirão aéreo', perdemos a sensibilidade para o horror ...
# 32       colunista: nova escola | folha - caveirao aéreo  https://www1.folha.uol.com.br/colunas/novaescol...
# 33       nova escola | as crianças da maré serão as nossas últimas testemunhas; com 'caveirão aéreo', per...
# 42       #acordamorador "caveirão aéreo" do governador continua aterrorizando as favelas do estado. agora...
# 47       após ação de witzel no “caveirão aéreo”, colégio coloca placa no teto: “escola. não atire!”  htt...
# 48       após ação de witzel no “caveirão aéreo”, colégio coloca placa no teto: “escola. não atire!”  htt...
# 75       vocês não sabem oque é dormir com medo dos tiros, vcs não  sabem oque é olhar da sua janela e  v...
# 198                         o dia em que eu falto aparece até o águia da polícia pousando no pátio da escola
# 226      polícia civil com águia helicóptero  atirad0r . sobrevoando em escola e casa de moradores jacaré...
# 227      polícia civil com águia helicóptero  atirad0r . sobrevoando em escola e casa de moradores jacaré...
# 247      ta que é pra denunciar já sabemos, mas quem ? os bandidos ou a policia que chega na favela em ho...
# 368      •o modelo no sp fashion week,  •carol bittencourt  •80 tiros... •uma família fuzilada pelo exérc...
# 481      gazelas acham que não existe escola de tiro com helicóptero kkkkk  uma aula deve se o preço de u...
# 501      seus filhos estão em escola pública? sugiro deixá -los um bimestre na escola municipal bahia na ...
# 509      importa quando o tiro vem de quem deveria proteger, importa quando o tiro vem da pm que achou qu...
# 615      as pessoas já acordam com helicóptero sobrevoando a comunidade, é tiro com criança indo pra esco...
# 629      mddc só agora vi a cena na novela das nove em q a escola é alvejada por tiros de um helicóptero ...
# 639      helicóptero chegou na comunidade aqui perto de casa do nada mano, deu p observar tudo... que bag...
# 643      tava tirando uma pestana aqui na escola de minha mae acordei com barulho de operacao muito tiro ...
# 661      eu vi o video e não vi tiros nem granadas, o helicoptero sobrevoava a area, é mais facil os band...
# 665      amada, retratou os tiros entre policiais e traficantes. se tu assistir a cena passa até um helic...
# 666      só  quem vive na favela sabe eu sou #cdd 15 aqui frequentemente  aonde tem várias  operações  , ...
# 679          #amordemãe triste realidade do rj essa cena do helicóptero sobrevoando a escola e metendo tiro.
# 680      amor de mãe mostrando tiro em escola ao som de helicóptero. um murro no witzel. espero que consc...
# 681      o tiro comendo no meio da aula... infelizmente é a realidade de muitas escolas aqui no rj. na mi...
# 684                    tiros vindo de helicóptero, a realidade das escolas das periferias do rio! #amordemãe
# 686         essa cena do helicóptero sobrevoando a escola, as crianças se encondendo dos tiros, mds que cena
# 687                            eu ouvi o helicóptero do whitney na cena do tiro comendo na escola #amordemãe
# 688      e essa cena do helicóptero passando por cima de uma escola, dando tiros? será que assim uma gale...
# 689          professor negra falando sobre escravidão numa escola e tiros vindo de um helicóptero. que cena!
# 691      que cena! uma escola pública recebendo tiros aparentemente de um helicóptero, alunos e professor...
# 694      que cenão!!!!!!!! o helicóptero que deu tiros numa escola, eu tô todo arrepiado, que novela é es...
# 698                                           o helicóptero dando tiro na escolaaaaaaaaaa caralho #amordemae
# 700                                          helicóptero passando em cima da escola dando tiro, deus me free
# 702                                 não são os comunista que tão dando tiro de .50 de helicóptero em escola.
# 703      tino júnior cagando pela boca mais uma vez, “helicóptero só atira pra baixo quando recebe tiro d...
# 742      na escola onde trabalho mtas crianças tem problemas c as ações da polícia. há uns meses, uma che...
# 767      e os cidadãos no meio do caminho, que tem furadeira, guarda-chuva, esquadrias confundida com ess...
# 768      não sei o que precisa acontecer pra esse país pegar fogo. só esse ano teve mais de 80 tiros do e...
# 772      coronel tadeu, você é um racista desgraçado  quantas crianças pretas foram baleadas esse ano, co...
# 776      o pior é que a bala é sempre da pm. mais de 80 tiros por confundir carro,por confundir gurada-ch...
# 816      acho que fui a única pessoa que não escutou helicóptero, tiro, nem nada, ainda perdi a hora da e...
# 818      tem um helicóptero em cima da minha casa, fazendo um barulho do caralho, já n fui p escola por c...
# 822                                indo pra escola dando tiro à beça tá até com helicóptero  deus me proteja
# 833      não, não  temos! minha esposa dá aula em escola pública e muitos alunos faltam ao colégio por pr...
# 850      pq ue virou comum foi helicóptero sobrevoando escola, policiais atirando primeiro, perguntando d...
# 872      amigo, num sei o que é mais crítico do que helicóptero atirando em escola e criança de oito anos...
# 881      pq se a milícia continuar no poder esquece esse negócio de escola. e se ainda exitir, vai tomar ...
# 890      sim pq é o helicóptero do traficante q atira em área de escola né é o traficante q atira em inoc...
# 906      @wilsonwitzel e aí seu governador, as crianças estão tudo na creche, escola é esse helicóptero d...
# 940      “não pode haver #operaçõespoliciais próximo das escolas. temos que ter uma lei sobre isso. já pa...
# 956                                 até em cima, de onde agora as escolas vem recebendo tiros de helicóptero
# 975      e também, bizarro esse "chama". alguém na escola lá pediu "por favor polícia, traz um helicópter...
# 991      grande dia 👍🏻 agr as crianças indo pra escola n vão levar mais tiro de helicóptero  https://twit...
# 999      eu n lembro da 1ª aula que perdi por isso. mas lembro da 1ª vez que tivemos que deitar no chão p...
# 1032     domingo tem eleição de conselheiro tutelar, mas como está difícil de achar listas concentradas c...
# 1036     quem deveria se arrepender?o paulistano e(ou)paulista q votou no psdb e está desempregado, sofre...
# 1054       tiro pra cacete helicóptero e os crl kethellen mesmo assim me inventa de ir pra escola pqp 😡😡😡😡😡😡
# 1062     teu comentário é equivocado e pode ser entendido como racista n caso ds problematizações "chatas...
# 1066     “o brasil não é um inferno intolerante” corta a cena pro helicóptero da pm do rio atirando em ca...
# 1068     de novo helicóptero do exército aterrorizando a quebrada, polícia trocando  tiro com bandido em ...
# 1078     ele pode entrar num helicóptero e ir trocar tiros lá.  é um pouco mais complexo que atirar em es...
# 1080     ansioso prós burgueses sentirem o que é tiro de fuzil nas costas e helicóptero atirando em cima ...
# 1093     o tempo todo fazemos. dê um google. não vai mudar o assunto. vocês matam crianças pelas costas, ...
# 1100     pra ele é segura sim, ele q tá do helicóptero dando tiro em escola. as crianças vão revidar como...
# 1150     a coisa mais tosca desse rir é esse espaço favela, puta merda.  vai ter rasante de helicóptero e...
# 1160     realmente! matar uma criança com tiros de fuzil pelas costas e atirar em escolas de helicóptero,...
# 1167     o problema das crianças no brasil é que tem beijo gay em gibi.  precisamos defendê-las.  foda-se...
# 1184     operação policial só fora do horário escolar e sem tiro de helicóptero  https://projetocolabora....
# 1189     operação policial só fora do horário escolar e sem tiro de helicóptero  https://projetocolabora....
# 1196     gente sera que no palco favela do rock in rio vai ter helicóptero atirando em escola e criança t...
# 1202     não é helicóptero dos bandido q dao tiro de cima para baixo em horário de escola, brasileiro ind...
# 1211     aqui temos governador que desce de helicóptero comemorando assassinato e militares fuzilando um ...
# 1215     tinha helicóptero atirando de cima': professores acalmam alunos com música durante operação que ...
# 1237     autorizar tiros de helicóptero em cima de escola foi surreal nesse governo e do outro lado tem d...
# 1240     exatamente, não tinha confronto! a mesma coisa quando deram 88 tiros no carro de um músico com a...
# 1242     urgente. maior apreensão de armas foi num condomínio de luxo do rj. urgente o rj precisa de mais...
# 1249     o + curioso do rj é q gravaram de 1 helicóptero de tv 1 grupo de bandidos fugindo de 1 ação da p...
# 1259     usar helicóptero para atirar em escola não é aceitável, foi isso que aconteceu essa semana, uma ...
# 1278     o genocida no caso é você, senhor governador. é inadmissível um governador do estado aparecer aq...
# 1280     enquanto houver quem relativize ou defenda, vai ter tiro em escola de dentro do helicóptero. enq...
# 1281     sou e mt. e leio bastante. posso lhe dizer que só de criança já foram 6. que uma escola e até um...
# 1282     não, você não imagina, mentiroso. o helicóptero da polícia não é despertador 5 da manhã no graja...
# 1283     🤣🤣🤣🤣 fogo cruzado sem ter tiro de volta é isso? o estado precisa avaliar os riscos de atirar. se...
# 1284     engraçado que a minha ideologia maligna não matou nenhuma criança, não deu 80 tiros numa família...
# 1287     tem vídeo da polícia com helicóptero planando e sentando tiro em escola, seu arrombado. vá a merda!
# 1289     então você tá dizendo que a guerra ao tráfico justifica o genocídio na favela? soube que sequer ...
# 1295     uma fatalidade na guerra? que guerra meu filho? a guerra está aí perto da sua casa? vc acorda co...
# 1313     precisa peitar traficante não. não são eles que matam as crianças e os moradores de favela, nao ...
# 1325     oportunismo e um governador sair de um helicóptero comemorando uma morte, metralhar um escola do...
# 1329     morte acidental numa rua na qual n havia tiroteio, deputada? vai dizer q foi acidental também os...
# 1335     é o estado federal,infelizmente ou felizmente,100% das favelas brasileiras sao o crime organizad...
# 1337     não, não. mais fácil mandar sair atirando e matando todos pobres no caminho. eles sabem q gente ...
# 1339     prefeito se preocupa tanto com crianças, pq não se manifestou sobre essa que tinha 8 anos e morr...
# 1343     aaah, então eles podem entrar na comunidade quando as crianças estiverem saindo ou indo pra esco...
# 1345     se a moralização passa por dar 80 tiros num carro de família, por matar jovens negros, por dispa...
# 1347     sabe qual é a resposta do witzel pra isso? mais violência, mais troca de tiro, mas helicóptero s...
# 1352     o @jornalextra destaca na capa desta sexta (20) o terror vivido por alunos de escola na maré: "(...
# 1357     "escola de comunidade é alvejada por tiros de helicóptero da polícia"  vai ser se alguma escola ...
# 1358     nenhuma palavra sobre uma criança morta. a 16a só esse ano. vc com a sua política assassina.  nu...
# 1378     eu ouvi o podcast do nexo sobre os tiros e me dava até ânsia de vômito de ouvir o som do helicóp...
# 1380     eu nunca tinha visto policia de helicóptero voando baixo na favela e por cima de escolas dando t...
# 1386                                                   se dar tiro de helicóptero em escola não mobiliza....
# 1387     testemunhas disseram que foi um só tiro. assim como o caso do menino aassassinado com roupa de e...
# 1388     no mínimo a polícia foi irresponsável, já que é básico que não se deve trocar tiros em áreas pov...
# 1389     a morta de agat não foi em conflito, para início de conversa. os tiros do helicóptero na escola ...
# 1391     enfrentamento é enfrentamento. o caso de hj não foi. vc entende que o discurso do witzel mudou a...
# 1395     o q me leva a crer é criança levando tiro, civil levando tiro, escola botando aviso pra não atir...
# 1397     passar pano cara sério? se o bandido morre ru quero mais é q se foda. esse discurso batido q ess...
# 1407     erra uma vez ou outra filha da puta????? crianças são mortas indo p escola, tem que se jogar no ...
# 1408     “morreu com um tiro de fuzil, nas costas, ágatha nesta madrugada. ela estava dentro de uma kombi...
# 1421     não é normal e não deve ser levado como normal todo dia um inocente morrer por "bala perdida" os...
# 1424     só neste ano: fuzilamento com mais 80 tiros, sequestro termina com execução, tiros disparados em...
# 1426     o mesmo estado que quer “preservar”  a criança de ver a imagem forte de dois seres humanos se be...
# 1431     precisa morar no rj, pra condenar um governador que prega extermínio de pobre? ou vc acha normal...
# 1432     e pra "resolver" todo esse problema, entra a policia na favela matando criança e dando tiro de h...
# 1437     sim. não tem lido as notícias? tiro de helicóptero em escola, comunidades, população civil acuad...
# 1438     ta irmão, mas oque que isso tem haver com o post? ce acha que o helicóptero dando tiro em região...
# 1441     pergunta básica, quantas vezes essa criança teve que se deitar no chão da escola pra fugir de ti...
# 1445     assassinatos como o de aghata acontecem há décadas e foram normalizados. se não cuidarmos estare...
# 1446          não tem como defender descer dando tiro com um helicóptero no horário de entrada de uma escola
# 1447     diga isso para os estados unidos, enjaulando crianças imigrantes em campos de concentração, ou à...
# 1450     helicóptero atirando em escola. menina negra morta por um tiro de fuzil nas costas.  o @wilsonwi...
# 1452     #repost @bertjoi with get_repost ・・・ agatha. 8 anos. tiro nas costas. estava dentro da kombi/lot...
# 1453     meninas de 8 anos: uma descreve quando, na quarta, o helicóptero de witzel atirou numa escola. a...
# 1454     reportagem em.que ele compara tiros de helicóptero em regiões próxima a escola com bombardeios  ...
# 1460     a apatia e a normalização de parte dos cariocas sobre crianças se protegerem numa escola de tiro...
# 1466     que escola foi metralhada? se uma escola tivesse sido metralhada umas 50 crianças estavam mortas...
# 1470     sobre subir morro, esse é o trabalho deles, se eles n subirem arriscando a própria vida n é vc q...
# 1471     #aculpaedowitzel, do bolsonaro e dos facistas que fizeram fã clube pra esses sociopatas! é helic...
# 1473     tiros na escola? ta fumando mto e financiando os que estão dando tiros no helicóptero da pm. mel...
# 1474     os tiros vêm do alto  ratátátá do helicóptero que sobrevoa as suas cabeças o fogo que mata crian...
# 1475     ágatha morreu com um tiro de fuzil nas costas nesta madrugada. ela estava dentro de uma kombi no...
# 1476     mais um inocente morto pela guerra da polícia contra a favela.. até quando isso vai acontecer?  ...
# 1486     apologia ao crime é a liberação de armas a civis e disparar tiros de helicóptero à escolas! isso...
# 1489                                                  helicóptero sobrevoando escola dando tiro pra baixo...
# 1493     te falar uma coisa: passar com a porra do helicóptero às 07 da manhã dando tiros em casas e esco...
# 1495     escola é alvo de tiros de helicóptero na maré: mais uma ação da política assassina de witzel  ht...
# 1498     não se faz sarcasmo onde crianças em uma escola são alvejadas por tiros disparados de um helicóp...
# 1501     fico na dúvida se o problema é burrice ou maucaratismo. quem vai apoiar helicóptero atirando à e...
# 1503     "a gente tava fazendo torcida para os meninos da nossa turma,tinha um campeonato de futebol. ai ...
# 1505     #rt @quebrandootabu: rt @fogocruzadoapp: o @jornalextra destaca na capa desta sexta (20) o terro...
# 1508                                                  e as escolas pra crianças só tomam tiro de helicóptero
# 1509     #rt @quebrandootabu: rt @fogocruzadoapp: o @jornalextra destaca na capa desta sexta (20) o terro...
# 1510     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1513                                           o que isso tem a ver com helicóptero dando tiro em uma escola
# 1514     com todo o respeito, mas se você não enxerga a gravidade de uma operação policial em área escola...
# 1516     pelo recorde alcançado em 9 meses de 2019 de ano em que o estado mais matou civis.  por estrangu...
# 1518     “imagens & história 2.0  crianças em uma escola da maré aterrorizadas com os tiros vindo de um h...
# 1520     quantos imbecis falando merda, pqp primeiro que não dá pra saber se os tiros são do helicóptero,...
# 1524     o @jornalextra destaca na capa desta sexta (20) o terror vivido por alunos de escola na maré: "(...
# 1530     o estado deve combater o tráfico sem por em risco a vida de civis! não importa o grau de dificul...
# 1536     engraçado que se ouve os disparos mas quem garante que não são os traficantes atirando no helicó...
# 1538     vocês imaginam seus filhos dentro da escola tendo que se proteger de tiros vindo de helicóptero ...
# 1539     sobre a polícia usando helicóptero e dando tiro em cima de escola você não se pronuncia, não é? ...
# 1540     e como estão as ações sobre a educação nas escolas da maré no rio? educação também é poder frequ...
# 1543     "traficantes comunistas roubam helicóptero da polícia para dar tiros em escolas" tipo manchete d...
# 1548     conta outra//tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes...
# 1553     claro po, o comandante deve ter acordado de mau humor e falado: "bora ali dar um rolê de helicóp...
# 1555     governador do rio de janeiro usa política genocida?????  https://youtu.be/6mcwmlpluay  via @yout...
# 1561                          ah ta, helicóptero da tiro em escola é é  o ministério da educação que vê isso
# 1564     "as crianças estavam brincando. o helicóptero passou, e todas começaram a correr. aí meteram tir...
# 1565     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1568     como seria a reação das pessoas se um helicóptero atirasse nos condomínios nobres onde apreendem...
# 1571     escola é alvo de tiros de helicóptero na maré: mais uma ação da política assassina de witzel  ht...
# 1572     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1574     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1577     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1579     “as crianças estavam brincando. o helicóptero passou e todas começaram a correr. aí meteram tiro...
# 1583     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1584     "lá na escola começou a dar tiro do nada, o helicóptero veio baixinho aí depois veio o helicópte...
# 1591     não consegui ver se é uma escola, um galpão, fábrica ou sei lá o q, não consegui ver se os tiros...
# 1596     onde que aparece os tiros saindo do helicóptero e indo pra escola? pra m parece que alguém está ...
# 1599     sabe o q consegue ser pior do q toda essa selvageria q o nosso governador vem promovendo no hell...
# 1600     não prenderam ninguém, traumatizaram crianças e ainda vem com um migué desses? pqp...  tiros de ...
# 1602     “essas crianças uniformizadas, dentro da escola, abaixadinhas com medo de tomar tiro de helicópt...
# 1603     lógica é simples: direito penal em tese deveria proteger bens jurídicos importantes - nome chiqu...
# 1604     tiros contra escolas na favela do alto de um helicóptero, crianças aterrorizadas: eis a política...
# 1608     lógica da direita brasileira:  gibi com beijo gay:   absurdo!! não pode, temos que agir para pro...
# 1609     nos anos 90 ia pra escola na favela onde morava e eventualmente os traficantes ligavam pra escol...
# 1610     o complexo da maré e do alemão foram alvo de operações nesta quarta pela manhã. em ambos os cená...
# 1611     o @jornalextra destaca na capa de hoje (19): "polícia sobrevoa a maré e dá tiros perto de escola...
# 1614     alunos da escola municipal wilian peixoto, na maré, zona norte do rio, afirmam que a unidade foi...
# 1616     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1620     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1621     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1622     deputada, por favor, informe em qual parte do vídeo os tiros estão sendo contra a escola?  da fo...
# 1624     tiros de helicóptero na maré, no rio, foram disparados para impedir que traficantes invadissem e...
# 1646     helicóptero e tiro as 6:30 da manhã, horário de ir pra escola, horário de trabalhador sair... é ...
# 1648     “as crianças estavam brincando. o helicóptero passou, e todas começaram a correr. aí meteram tir...
# 1650     #bdrj o  veloso explica uma coisa e vem fachel e volta a falar merda.  não houve tiro para escol...
# 1655     um tiroteio do krl a hora das pessoas ir trabalhar,as crianças indo pra escola. helicóptero dand...
# 1663     tá tendo operação da polícia eu acho, aí o helicóptero tá largando varios tiros aqui pra baixo, ...
# 1686           chorando pq o helicóptero tá dando tiro justamente onde eu preciso passar para ir para escola
# 1691     o ultra conservador burro quer que, a mesma criança aterrorizada com os tiros de um helicóptero ...
# 1695     escola é alvo de tiros de helicóptero na maré: mais uma ação da política assassina de witzel  ht...
# 1697     me pergunto até onde isso é verdade. acho impressionante quem acredita que o comando da polícia ...
# 1698     não adianta. tem que falar a verdade mesmo. um cara desse é burro. não consegue entender porque ...
# 1700     *menciono os tiros de helicóptero sob a escola na maré*  meu padrasto, vulgo apoiador do bolsona...
# 1701     ai brasileiro aplaude witzel que mete medo em escolas com helicoptero dando tiro a esmo sem obje...
# 1705     parece inacreditável, mas n é. para quem n conhece, o helicóptero está sobrevoando escolas, sim,...
# 1707     de um lado uma escola levando tiro de um helicóptero de outro as pessoas falando que é transfobi...
# 1714     escola é alvo de tiros de helicóptero na maré: mais uma ação da política assassina de witzel  ht...
# 1716                       fake ? o vídeo tá em todo lugar , helicóptero estava dando tiro em cima da escola
# 1717                   mas se as escolas fossem militarizadas elas poderiam revidar os tiros do helicóptero!
# 1721     tu tá vendo as notícias não ? ou os vídeos ? crianças de creches abaixadas , tiros batendo na es...
# 1729     essas crianças uniformizadas, dentro da escola, abaixadinhas com medo de tomar tiro de helicópte...
# 1730     #witzelassassino imagina lá no eua que esses reaças tanto amam, um governador mandando da tiro d...
# 1734     essas crianças uniformizadas, dentro da escola, abaixadinhas com medo de tomar tiro de helicópte...
# 1739     pqp... ela pediu escolta pra se proteger ! não está errada  no outro ela está sendo contra a ope...
# 1741     usar um helicóptero como plataforma de tiro em direção a uma escola cheio de crianças é super no...
# 1744     eu acho que a deputada deveria ser chamada para testemunhar sobre o caso, já que ela como perita...
# 1746     se colocasse numa história o que aconteceu hoje no rio de janeiro, as pessoas diriam que é inver...
# 1750     a necropolítica de witzel segue. hj, o complexo do alemão amanheceu sob tiros. foram cerca de 15...
# 1751     escola é alvo de tiros de helicóptero na maré: mais uma ação da política assassina de witzel  ht...
# 1753     vc q vive nesse inferno (como vc diz) deveria ter mais empatia e saber q chegar com um helicópte...
# 1754     hoje senhor general crianças ficaram acuadas dentro de uma escola na maré no rio de janeiro sob ...
# 1756     ah é, vc acha "corretíssimo" um helicóptero sobrevoar uma escola em horário de aula e do alto da...
# 1757     renato cinco · 1 h ·    escolas da maré na mira do tiro | alunos de escolas na maré passaram mom...
# 1758     entendi .os bandidos vitimas da sociedade não atiraram no helicóptero que agora é blindado ; os ...
# 1763     agora me diz, vc acha certo uma escola ser alvo de tiros do helicóptero da polícia do rj? ah, e ...
# 1765     "alunos afirmam que helicóptero da polícia civil atirou em escola na maré, zona norte do rio des...
# 1766     infelizmente não há uma análise crítica sobre o absurdo q é um helicóptero dar rajadas de tiros ...
# 1768     *beijo gay* conservadores: 😭😭 temos que proteger nossas crianças *crianças encurraladas na escol...
# 1769     "as crianças estavam brincando. o helicóptero passou, e todas começaram a correr. aí meteram tir...
# 1770     ação da polícia do rio de janeiro nas favelas: tiros a esmo vindos de helicóptero, de cima pra b...
# 1772     eu acho uma covardia mano, os cara dar tiro de cima do helicóptero e sobrevoar as escolas. gente...
# 1774     um helicóptero dando tiro na favela perto de escolas. na moral, ainda tem gente que bate palma p...
# 1790                 champions league na europa e helicóptero dando tiro na maré próximo a escola mais cedo.
# 1794     paulo eduardo gomes· 53 min ·    crianças em uma escola da maré aterrorizadas com os tiros vindo...
# 1803     como??? se vc autoriza operação que da tiro a esmo de um helicóptero e ainda por cima sobrevoand...
# 1807     tem polícia dando tiro de helicóptero em escola e lambe-bota "cidadão de bem" aplaudindo  https:...
# 1809     usar a escola como ponto de sobrevoo é ainda mais irresponsável. o helicóptero é o alvo preferen...
# 1810     tiros de helicóptero da polícia contra uma escola. a necropolítica de wilson witzel leva o rio d...
# 1812     "as crianças estavam brincando. o helicóptero passou e elas começaram a correr. todo mundo grita...
# 1818     não dá para cair na falácia de que "todos nós temos oportunidades iguais" ou "só ñ estuda quem ñ...
# 1819     crianças em uma escola da maré aterrorizadas com os tiros vindo de um helicóptero utilizado como...
# 1822     a necropolítica de witzel segue. hoje, o complexo do alemão amanheceu sob tiros. foram cerca de ...
# 1823     todos os dias por ordem do governador nossos jovens e crianças são assassinados,  q não literalm...
# 1825     esse é o governo do wilson witzel, helicóptero sobrevoando em cima de escolas.mandando tiro para...
# 1828     uma escola municipal da maré foi alvo de tiros de um helicóptero da polícia. os estudantes tiver...
# 1833     não dá para cair na falácia de que "todos temos oportunidades iguais" ou "só ñ estuda quem ñ que...
# 1835     helicóptero sobrevoando e dando tiros ontem o aglomerado da serra, em bh. witzel fazendo escola....
# 1846     se explodirem esse helicóptero, mandam mais dois, pelo menos. as pessoas adoram ficar comovidas ...
# 1860     hahahahahahhha é sim, é sim... escolas de elite deixam de ter aulas todos os dias porque tem hel...
# 1869     tmnc desses cara que vem pra aterrizar a comunidade mané, tmnc desses "favelados" que votaram ne...
# 1873     será que hoje teremos mais moradores,pessoas do inocentes nas estatísticas?   onde já se viu hel...
# 1875     essas porra n pensa não? que tem crianças nas escolas, bebês nas creches pessoas indo trabalhar ...
# 1878     é inaceitável essa "operação" de guerra com tiros de helicóptero que moradores do complexo do al...
# 1887     isso é hora dessa porra desse helicóptero vim dar tiro ?! 🙄 pqp 😠 que deus proteja nossas crianç...
# 1889     caralho mano, do nada o helicoptero brotou aqui e começou a dar tiro mano, cheio de gente na rua...
# 1891     witzel vc é um covarde . é isso aí que vc faz um helicóptero dando tiro próximo a escola . 😡😡😡😡 ...
# 1926     minha mãe já me manda mensagem avisando que meu irmão não vai poder ir pra escola porque acordar...
# 1942     alemão tem tiros de helicóptero em ação da pm; policial é baleado e, segundo moradores, 14 escol...
# 1946     tá repetitivo falar de helicóptero da polícia dando tiros na favela mesmo, pois está acontecendo...
# 1953     são 07h e já tem helicóptero dando tiro em cima da casa dos moradores e caveirão rodando pelas r...
# 1978     caralho acabei de acordar e ja helicoptero zanzando por aqui tiro pra caralho gente pelo amor de...
# 2031     um helicóptero sobrevoa a favela de jacarezinho distribuindo tiros, enquanto outros agentes, por...
# 2034     queria saber o que passa na cabeça desse governador que ñ se toca que as crianças tem que estuda...
# 2048     polícia do witzel pratica tiro ao alvo à distância dia sim dia não nas comunidades do rio  mata ...
# 2077     helicóptero dando muito tiro... justamente no horário q tem muita gente indo trabalha,crianças i...
# 2087     eu sinto o medo e o ódio desses tiros vindos do helicóptero. lembro até hoje de quando chegou at...
# 2091     operação policial na hora de entrada para escolas, pais, mães e trabalhadores desesperados. o he...
# 2113     muito tiro, eles chegam atirandon e não querem saber se tem morador na rua, indo trabalhar ou cr...
# 2135     isso é maior covardia ficar dando tiro do helicóptero, ainda mais nesse horário, tanta gente ind...
# 2137     70% que acobertam, já receberam ajuda dos traficantes. aqui o sentido é inverso, aqui cai granad...
# 2140     polícia civil, brigada militar, patrulha escolar e um helicóptero nos arredores do bairro rosa m...
# 2142     bandidos roubaram 1 carro e trocaram tiros com a polícia aqui no bairro vizinho e que eu levo mi...
# 2188     aflição de ver o povo postando esses relatos de tiro, helicóptero... só deus cara, quem sofre é ...
# 2214     observem para onde vai os disparos que sai do helicóptero feito pela criança, os tiros vão em di...
# 2219     ameaças reais, hahahaha. ameaça real sobre quem leva tiro de helicóptero na escola. vai lá e apr...
# 2222     crivella: temos que proteger nossas crianças also crivella atirando em escolas de um helicóptero...
# 2228     olha seu crivella, eu n sei n mas sabe um jeito mt eficiente de proteger "nossas crianças"? não ...
# 2237     pode chover tiro de helicóptero da polícia em escola, mas o que tem que proteger é criança de be...
# 2238     o prefeito deveria proteger as crianças que são alvejadas pelos tiros do helicóptero do witzel d...
# 2267     hoje é sobre educação, aí mostram imagens das criancinhas em uma escola na favela se protegendo ...
# 2273     exatamente, é o que falei a deputada tem salário compatível pra pagar um colégio seguro e bom pr...
# 2298     quando uma criança moradora de uma comunidade pobre do rio de janeiro a caminho da escola recebe...
# 2313     aqui tá cheio de policial, helicóptero e os cacete tomara que quando eu saia p ir pra escola eu ...
# 2317     mentalizei pra acordar hoje mas não imaginei que o despertador seria o helicóptero do witzel dan...
# 2354     a vida de um morador de favela é tenso demais, você já acorda com tiros, não sabe se vai poder i...
# 2360     eu aqui inocente achando que o black twitter e o movimento preto tinha coisa mais importante par...
# 2386     e moradores reféns disso, tiros e rajadas frequentes, helicóptero atirando de cima,e o direito d...
# 2394     mas ele são traficantes, são bandidos. agora o foda é um policial, pago com com meu dinheiro, qu...
# 2410     eu até acharia minimamente aceitável se a gente não conhecesse o governador, mas é o cara que so...
# 2439     é óbvio que não cidadão, mas a polícia tem que medir riscos dos locais que atira. se no local qu...
# 2492     agora fodeu! mataram e estão sendo aplaudidos! heróis! e os mortos da semana passada? e o helicó...
# 2502     mas ele foi pra se aproveitar msm...queria ter visto ele indo hoje na cdd hoje as 06:00,  helicó...
# 2518     aqui na maré o helicóptero passa dando tiro na rua, com as crianças saindo da escola. aí na pont...
# 2537     helicóptero da polícia ta em cima da minha casa soltando tiro pra cdd, duvido q eu vou pra escol...
# 2574     tem criança que entra em desespero só de ouvir barulho de helicóptero, criança perdendo gente qu...
# 2592     chorei horrores hoje lendo a noticia da mãe falando que o filho tava indo pra escola e fugiu dos...
# 2615     pra de proteger de tiros de helicóptero, escola coloca uma placa de identificação. no rio, políc...
# 2618     eu moro próximo da maré e sempre acordo ao som de tiros e helicóptero dando razantes na comunida...
# 2622     essa semana a entrega da carta das crianças para o governador mandando parar de atirar  tá tendo...
# 2633     é invadir matar e depois perguntar, são pessoas que podiam dar bons frutos se transformando em p...
# 2649     o grupo que é a massa fascista é aquela classe média/ média alta/ elite que está babando de ódio...
# 2665     combater crime 6:40 da manhã dando rasante de helicóptero, dando tiro aesmo em cima de escola na...
# 2675     “um dia eu tava na escola no patio fazendo educação física aí de repente o helicóptero passou da...
# 2680     "um dia eu estava no pátio da escola fazendo educação física. de repente, o helicóptero passou d...
# 2686     "um dia eu estava no pátio da escola fazendo educação física. de repente, o helicóptero passou d...
# 2712     a polícia passa de helicóptero dando tiros em direção a escola de crianças. atira 80 vezes contr...
# 2713     "um dia eu estava no pátio da escola fazendo educação física. de repente, o helicóptero passou d...
# 2719     "um dia eu tava no pátio da escola fazendo educação física. de repente, o helicóptero passou dan...
# 2721     "um dia eu estava no pátio da escola fazendo educação física. de repente, o helicóptero passou d...
# 2722     "um dia eu estava no pátio da escola fazendo educação física. de repente, o helicóptero passou d...
# 2723     "um dia eu estava no pátio da escola fazendo educação física. de repente, o helicóptero passou d...
# 2724     "um dia eu estava no pátio da escola fazendo educação física. de repente, o helicóptero passou d...
# 2726     "um dia eu estava no pátio da escola fazendo educação física. de repente, o helicóptero passou d...
# 2728     “um dia eu estava na escola, no pátio, fazendo ed. física e aí, de repente, o helicóptero passou...
# 2730     talvez pq no dia das aulas de português tinha um helicóptero dando tiro na rua da escola delas 🤷...
# 2737     namoral bglh maior parada 7horas da manhã vem helicoptero da policia civil e dispara imensa quan...
# 2776     crlho os meg ta atirando do helicóptero pra baixo, desnecessário pprt, tao nem recebendo tiro de...
# 2778     helicóptero passando, dando tiro e o rodrigo acha que tá tranquilo pra sair de casa que ir pra e...
# 2783     várias crianças indo pra escola e a polícia vem de helicóptero largando tiro pra dentro da favel...
# 2790     governador tem escola estadual sem  professor !!! mais num falta dinheiro pra dar tiro de helicó...
# 2796     imagina essa gente revoltada com o cara q matou a filha saindo da cadeia, cumprindo o rito legal...
# 2814     discuti c a mulher do grupo da van da kaylla, helicóptero dandi tiro ela quer pq quer q o cr sai...
# 2815                  helicóptero dando tiro, caveirão na pista e tem mãe q ainda manda criança pra escola 🙄
# 2846     enzo tá na escola e eu com medo de ir buscar, eles tão dando mt tiro do helicóptero aqui p baixo...
# 2848       vou comprar uma arma pra derrubar helicóptero se eles continuarem dando tiro na direção da escola
# 2855     [6/8 06:32] tia lucia♡: bom dia, cuidado que está dando muito tiro, helicóptero está na área [6/...
# 2857                          tava mó animada para ir a escola e vem esse helicóptero mandar tiro, aou merda
# 2969                   e eu vou mandar prender terrorista que fica dando tiro em escola de helicóptero, e aí
# 3086     democracia e cidadania são ideias abstratas para que mora num bairro de periferia, e que pode le...
# 3186     mataram um cara e colocaram fogo nele do lado da escola durante a noite, outra vez foi que um me...
# 3213     vai tomar no nosso cu, hoje teve “operação” em vaz lobo e tavam sobrevoando com helicóptero dand...
# 3321     oi, governador. não sou famosa nem rica e ruiva, mas quero um favorzinho também se puder. a polí...
# 3398     sim, pq 80 tiros em um carro é super cool morrer pq seu guarda-chuva e confundido com um fuzil e...
# 3412     vagabundos safados, passam pano para miliciano e narcotraficante para dps governador  do rio fic...
# 3531     para muita gente no local que essa criança sobrevive não deve ter centro comunitário, creches, e...
# 3537     tipo governador atirando de helicóptero, milicianos matando juízas e vereadoras honestas? é dess...
# 3550     não vou pra escola pq falaram que tá dando tiro lá e o helicóptero tá aqui kkkkkkkkkk, show perd...
# 3554     1 - papel da polícia não é "matar bandido" e só isso já mata esse seu péssimo argumento. 2 - os ...
# 3569     já deu tiro de helicóptero, falta montar o esquema da prostituição. alguém levantou os nomes no ...
# 3608     é bem complicado morar no rj e dia sim, outro tbm, acordar com cenas de operação em alguma comun...
# 3614     ala o helicóptero dando tiro pra baixo sem direção com crianças indo pra escola e moradores indo...
# 3695     alguém mete um monte de tiro em porta de escola. normal. mesada na cabeça de professor. toleráve...
# 3716                    estava um helicóptero voando aq, podia bem dar uns tiros p nada, quero ir p escola n
# 3751                      infelizmente não vou poder ir p escola, caveirão, helicóptero, tiro... poxa kkkkkk
# 3752                 infelizmente não vou poder ir pra escola, caveirao, helicóptero, tiro.. poxa kkkkkkkkkk
# 3782     o mesmo governador que brincou de tiro ao alvo perto de área escolar, de dentro de um helicopter...
# 3835     ditador assassino alguma glória nisso? governador do rio está copiando o ditador  quantos corpos...
# 3866     o "machão atirador" witzel gosta é de dar tiro de dentro do helicóptero,em pobres e crianças ind...
# 3873     não são nem uma da tarde e já tem helicóptero dando tiro na favela, policial metendo fuzil na ca...
# 3944     realmente, quando um governador acha ok subir num helicóptero e brincar de sniper fica difícil u...
# 3955     esses alienados pensam que brasil é conto de fadas, que mamãe e papai sentam na beira  da cama d...
# 3957     caos é matar pai de família com 80 tiros, atirar na cabeça de professor, atirar de helicóptero e...
# 3961     porque a pm mata inocente e ficaria por isso mesmo? porque escolas colocam placas avisando que a...
# 3965     enquanto isso, escolas do rio de janeiro precisar colocar placa de “não atire” no telhado para q...
# 3970     o maluco só pensa em: tiro na cabecinha, polícia, helicóptero, polícia, tiro de helicóptero, pol...
# 3980     vi foto sua do lado do flávio. 🤔 tb tinha o governador q anda d helicóptero atirando em pobre da...
# 3985     enquanto o senhor crivella tá preocupado em tirar a única forma de sustento de muitos, apreenden...
# 3987     essa merda tava rolando uma hora seguida esse helicóptero sobrevoou ali. só ali! na favela!  nun...
# 3999     na segunda-feira, 13, era a outra filha, de 13 anos, que estava na escola quando os tiros começa...
# 4003     fala isso pra logo em seguida subir em helicóptero pra dar tiro em criança saindo da escola  htt...
# 4004     é importante investigar o crime organizado na raiz, mas witzel age dando tiro de fuzil a esmo do...
# 4041     o cuidado do estado com qum é de área periférica é 0.  horário que crianças saem da escola e tem...
# 4042     mais um dia, mais um dia no horário de crianças transitando na rua, horário de saída de creche, ...
# 4045                      helicóptero sobrevoando a favela e tacando tiro pra baixo dnv, na saída da escola.
# 4060     isso é livramento,porraaa faz 10 minutos q eu cheguei c a thalia da escola,pqp, helicóptero da t...
# 4069     verdade né, terrível os militares dando 80 tiros no carro de um inocente ahh, isso foi no brasil...
# 4073     vou te dizer quantas vezes uma família de ricos e brancos foi atacada pela polícia com 84 tiros;...
# 4077     grande governo: escola do rio usa placa no teto para evitar ser alvo da polícia em tiros de heli...
# 4090     alguma coisa muito errada está acontecendo com esse país essas imagens viralizaram no mesmo dia ...
# 4093     é pq a polícia entra na favela de helicóptero atirando para baixo, muita das vezes sem direção, ...
# 4099     “escola, não atire”: é o que diz em uma placa no telhado da escola uerê, complexo da maré, rio. ...
# 4102     olha só na porra do nível que a gente chegou! uma escola tendo que informar no seu telhado do qu...
# 4113     infelizmente chegamos a esse ponto, sinalizar uma escola para não ser alvejada por tiros de um h...
# 4114     vamos retuitar até chegar ao @wilsonwitzel para ele lembrar o que são escolas  “escola, não atir...
# 4117     pq ela mais que certa, o denunciou p onu pelas merdas que ele tá fazendo se dizendo "querer acab...
# 4126     manda o governador morar na maré e ver o que é acordar com o helicóptero praticamente no teto da...
# 4134     hoje tem um debate entre o governador do rio, wilson witzel (aquele que voou de helicóptero para...
# 4136     como age a esquerdalha: post da deputada do psol sobre uma placa numa escola no rio, 1 dia após ...
# 4139     as crianças da periferia do rio de janeiro estão com medo de morrer dentro de suas escolas porqu...
# 4150     não vejo inteligência nem investigação só vejo tiros a esmo de alto de um helicóptero e bala "pe...
# 4151     gente, eu chorei com essa imagem. a escola, na favela, tendo que se identificar para não ter per...
# 4155     a que ponto é preciso chegar para proteger as pessoas? escola no rio de janeiro coloca placas co...
# 4178     "do tipo que explode carro em frente a escola, dá tiro em uma rua sem olhar onde ta indo a bala"...
# 4237     "juristas evangélicos"  são aqueles tipo o governador do rio de janeiro   que sai de helicóptero...
# 4238     "juristas evangélicos"  são aqueles tipo o governador do rio de janeiro  que sai de helicóptero ...
# 4270     é bem isso... um sádico que adora tirar selfies da suas atitudes fascistas. e que já liberou sni...
# 4295     sem precisar dar tiros de helicóptero na porta de uma escola no horário de saída dos alunos? cla...
# 4297     se dum helicóptero policial, à plena luz do dia e com a população lá embaixo, sai um tiro que at...
# 4303     não sei, mas por que levaram um tiro vindo de um helicóptero são bandidos? quem garante? e a pro...
# 4323     prenderam fazendo o que? usando a inteligência. não fazendo incursão policial com um helicóptero...
# 4324     foi o tempo em q a gente saía da escola correndo e fazendo aposta de quem chegaria em casa prime...
# 4325     imaginem as crianças da escola britânica ou da escola nova, onde 9 entre 10 filhos de artistas e...
# 4333     existe operação hollywoodiana (helicóptero, disparos em meio a população civil, crianças em pâni...
# 4352     crianças saindo da escola se desesperaram com os tiros vindo do alto, do helicóptero da core, na...
# 4358                             nosso governador sobe em helicóptero e dá tiro em horário de saída escola..
# 4403     deem tiro e sobrevoem com helicóptero aq na minha escola tb, adiem as aulas até o final do ano e...
# 4405     ontem no rio centenas de crianças protestaram na rua por direito a ensino público de qualidade n...
# 4411     qdo disserem q “ cotas é um previlégio” mostre essa foto.  privilegiado é vc, q não ta levando t...
# 4434     atiraram de helicóptero na maré e as crianças na escola tiveram que se refugiar pra não levar tiro.
# 4435     estão dizendo que o jn não mostrou a matança na maré, rajadas de tiros a esmo de helicóptero com...
# 4444     crianças saindo da escola se desesperaram com os tiros vindo do alto, do helicóptero da core, na...
# 4447     dudu...isso aqui é a faixa de gaza...é polícia de helicóptero sobrevoando escola dando tiro a es...
# 4455     kkkkkkkkk eu acabei de ler um 'que bom' em resposta à policia dando tiro de helicoptero em horar...
# 4469     numa foto, as crianças saem da escola, tentando se proteger dos tiros  do helicóptero que sobrev...
# 4487     "moradores denunciam que o helicóptero da polícia atirou do alto no horário em que as crianças s...
# 4491     operação nos bairros entorno da escola hj. tiro, fogos, helicóptero, relato das crianças e escol...
# 4497     tiros de um helicóptero em direção a uma escola.  https://twitter.com/casodepolicia/status/11254...
# 4505     moradores denunciam que o helicóptero da polícia atirou do alto no horário em que as crianças sa...
# 4508     moradores denunciam que o helicóptero da polícia atirou do alto no horário em que as crianças sa...
# 4526     naturalizar o extermínio de pretos e pobres. é isso que vocês querem? olhem para essa foto. agor...
# 4528     muito cruel.operações policiais são necessárias, mas com inteligência,ocupação de território e o...
# 4529     expectativa: cenas de cinema pra botar na campanha de rodrigo amorim ano que vem.  realidade: cr...
# 4534     helicóptero descendo a bala, crianças de uma escola correndo, famílias se escondendo dos tiros! ...
# 4546     atenção! um helicóptero da polícia está sobrevoando agora a maré e causando um terror em morador...
# 4553     atenção! um helicóptero da polícia está sobrevoando agora a maré e causando um terror em morador...
# 4555     tá tendo operação na maré. criança nas escolas.... muito tiro do helicóptero. ninguém entra e sa...
# 4564     enquanto isso no plantão maré: avisa pra escola não liberarem as crianças por causa dos tiros. "...
# 4591     na década de 80, a gente tinha governador que chegava na favela a pé para queimar armas de brinq...
# 4748     capivari tá tenso hoje, eu cheguei da escola ouvi três tiros e depois passou dois carros da polí...
# 4826                                     tô querendo ir pra escola o helicóptero dando tiro vai se fude mane
# 4968     tinha q sair uns tiros pra eu não ir pra escola kkkkkk q ódio,  continua passando helicóptero 🤦🏽...
# 4995     manda fazer isso com as criancas negras de escola pública em vez de ataca-las a tiro de helicóptero
# 5024     caralho favela tá muito lombrada kkkkkkkkk helicóptero lá na escola dando vários tiros sai correndo
# 5045     milena santos: vai inaugurar uma escola aqui perto da casa da minha mãe e o crivella confirmou p...
# 5069     [21/3 08:43] mãe ❤: quando estiver vindo embora cuidado [21/3 08:43] mãe ❤: o helicóptero tá aqu...
# 5084     como que 3 horas da tarde, horário de saída de criança da escola a polícia chega de helicóptero ...
# 5094     os cara ta dando varios tiros do helicoptero mano, tem noção disso? são 2 helicoptero... varias ...
# 5152     e isso anula o fato deles estarem em área residencial em um horário de saídas para trabalho e es...
# 5190     outra coisa que não consigo entender, uma operação dessa, helicóptero dando tiro, ninguém na rua...
# 5294     o brasil funciona assim: pra apreender um fuzil na favela, matam 10 pobres. pra 117 na mansão em...
# 5305     mais uma vez fui chamado de ptista maluco maconheiro, que preciso de tratamento. causa: disse qu...
# 5306     tragédia em suzano/sp  tiros deixam oito feridos em escola de suzano; há crianças entre as vítim...
# 5309     tiros deixam oito feridos em escola de suzano  o corpo de bombeiros foi acionado para atender a ...
# 5312     tiros deixam oito feridos em escola de suzano; há crianças entre as vítimas, diz polícia bombeir...
# 5313     tiros deixam oito feridos em escola de suzano. há crianças entre as vítimas, diz polícia bombeir...
# 5314     agora sp: tiros em escola de suzano, em são paulo, deixam crianças feridas. as informações indic...
# 5343     sem dar tiro, sem helicóptero metralhando telhados, sem escolas fechadas..... parabéns! tem que ...
# 5365     exatamente, irmão. pensei igual. se fosse aqui, porram! já estava sem luz, escolas fechadas, “ch...
# 5482     é muita canalhice achar que o mal maior é vender maconha, e não o fato de dar tiro de helicópter...
# 5558     isso me faz lembrar de quando vieram instalar a upp no arará. mais ou menos umas 6h da manhã, ho...
# 5560     militante brigando por escola de samba enquanto tem preto morrendo de tiro dado de cima de helic...
# 5675     somos moradores, somos reféns de tudo isso.  nao merecemos ser acordados ao som de tiros, com he...
# 5792     [27/2 06:59] sthefany mello: tô indo p escola jaja [27/2 06:59] dudinha ❤️: vem cm muito cuidado...
# 5799     lá vai eu ir pra escola no meio dos tiros, helicóptero em cima, essa salgueiro tá difícil essa s...
# 5805     ajudar? bozominion ajudar nordestino? favelado? nesse pais matam crianças indo pra escola com ti...
# 5851     hj de manhã quando acordei p ir p escola escutei tiro a beça, helicóptero passando mto baixinho,...
# 5878      eu coloquei a maria na escola voltei e apaguei, n ouvi tiro, n ouvi helicóptero, n ouvi nada viado
# 5882     quem ta de fora fala muita coisa sem conviver, muito fácil olha pela tv e ver só oq eles querem ...
# 5955                                     tiro. já não vou pra escola pq nem da até helicóptero tem que uor🙄🤣
# 6013     tipo o menino q tava voltando da escola e tomou um tiro q veio de um helicoptero? ele nao tinha ...
# 6399     que falsa simetria hein o país ta sofrendo economicamente por embargos, derrubando o preço do pe...
# 6574     hoje eu sonhei que tava acontecendo uma guerra, tinha um helicóptero com metralhadora atirando e...
# 6598          meu sonho que esse helicóptero sobrevoando minha área desse uns tiros pra eu não ir pra escola
# 6647     uma hora da tarde e esse helicóptero surge dando tiro pra caralho pro aí, na hora que varias cri...
# 6836     queria ver era a nota de repúdio da mãe do menino que estava com a camiseta da escola e morreu c...
# 6906     e eu q tava na frente da escola esperando pra ir embora e do nada começou a ter tiro perseguição...
# 7090     nao posso ir pra escola pq ta dando tiro, agr nao posso dormir pq o helicóptero ta aqui em cima,...
# 7226     repórter do @portaluol acha que está em #londres. sem helicóptero como plataforma de tiro, sem o...
# 7297     geral falando de helicóptero e tiro, ainda bem que eu estava na escola e não vi e nem ouvi nada ...
# 7516     voltando pra casa porque o helicóptero da pol tá trocando tiro c bandido perto da escola que tra...
# 7619           hj passou um helicóptero em cima de casa eu comecei a gritar "tiro tiro", só pra n pra escola
# 7666         eu to puta pprt vtnc, já começou esse helicóptero e os tiros... tenho que ir p escola nesse crl
# 7687     bom dia? aqui na maré acordamos  ao som de helicóptero com voos rasantes, muitos tiros e gritari...
# 7821                                helicóptero passou pertinho da escola dando tiro, nem assim eles liberam
# 7839                                 helicóptero tá passando baixinho aqui na escola, dando tiro pra crlh...
# 7894     eu acordei cedo mas não vou pra escola porque o helicóptero da polícia não para de passar aqui e...
# 7904                         porra ta tendo mt tiro aki e ta passando um helicóptero num queri ir pra escola
# 7922     a de assalto, b de banco, c de calote, d de droga, e de escola, f de facada, g de gangue, h de h...
# 8027     #enfiemaspanelasnocu toda a rede de corrupção que aprovou a intervenção militar no rio. #mariell...
# 8048     vou te dizer não pode caveirão, não pode helicóptero, não pode chegar perto de escolas..  a comu...
# 8102     falar de meritocracia sem correr risco de tomar tiro de helicóptero indo pra escola é mole.  htt...
# 8105     estamos no país que criança em uniforme de escola toma tiro nas costas a partir de disparo de he...
# 8107     me perguntam pq eu ando tão adepto da violência. o nosso país tem bolsonaro. tem criança de unif...
# 8110     “mãe, ele não viu que eu estava com roupa de escola” caralho, um garoto desses não merecia morre...
# 8132     e pensar q o choro do neymar gerou + debates e reflexões no país do q o choro da mãe do menino m...
# 8135     retweeted carlos minc (@minc_rj):  amigos vejam que tristeza: população da maré tratada como exé...
# 8136     quando é a semana com informações sobre os males causados pela proibição das drogas?? tipo tiro ...
# 8144     amigos vejam que tristeza: população da maré tratada como exército inimigo, tiros de helicóptero...
# 8145     e pensar que o choro do neymar gerou mais debates e reflexões no país do que o choro da mãe do m...
# 8149     marcos vinícius da silva,estudante-14 anos mais d 100 tiros vindo do helicóptero distribuídos pe...
# 8150     essa parada do menino q tava a caminho da escola e foi morto por tiros de um helicóptero é mt ab...
# 8157     uma guerra sustentada pelo estado que combate a droga de forma errada, invade a favela trocando ...
# 8159     senti muito quando o filho do geraldo alckmin morreu em um acidente de helicóptero. me decepcion...
# 8165     retweeted andrea werner (@lagartavirapupa):  morreu mais um estudante. morreu porque morava na m...
# 8167     atirar de helicóptero???? onde eles pensam que estão? com quem eles pensam que estão lidando? se...
# 8170     ele contou que o menino tentou ir para a escola, mesmo atrasado, mas resolveu voltar para casa a...
# 8172     mas e o menino de 14 anos que foi atingido pela policia indo p escola? 100 marcas de tiros a mai...
# 8174     morreu mais um estudante. morreu porque morava na maré. porque ia pra escola em meio a uma opera...
# 8176     marcos vinícius tinha 14 anos. foi baleado a caminho da escola, no complexo da maré. antes de mo...
# 8184     exato. não foi acidente, não foi acaso: 100 tiros despejados de um helicóptero nas proximidades ...
# 8187     vc vai pra escola e toma um tiro de helicóptero  https://twitter.com/blogfeministas/status/10098...
# 8192     é copa de um lado e do outro é um adolescente com uniforme escolar morrendo na favela com tiro d...
# 8196     ai um guri, de 14 anos, se atrasa pra escola e no caminhão leva um tiro (??????) helicóptero ati...
# 8197     ontem um helicoptero sobrevoou a maré dando tiros em alguns alvos. mataram 7, um deles era um ga...
# 8202     “marcos vinícius, estudante de 14 anos é assassinado com tiros do helicóptero a caminho da escol...
# 8208     um minuto para chamar a atenção para o que aconteceu no complexo da maré ontem. oficialmente a i...
# 8210     como diria a marielle: quantos mais vão ter que morrer? mais de 100 tiros disparados covarde e i...
# 8217     "o menino tentou ir para a escola, mas resolveu voltar para casa ao ouvir os primeiros tiros par...
# 8218     rasantes de helicóptero e sete mortos em dia de pânico na maré, no rio. em ação que revoltou mor...
# 8225     resumo da segurança pública no rj:   no complexo da maré: 7 mortos entre eles um menino que ia p...
# 8227     mano um mlk de 14 tiros levou tiro dum policial que tava num helicoptero quando tava indo pra es...
# 8240     rj - “é inaceitável ver helicóptero atirando", diz diretor de ong na maré  https://buff.ly/2k8rl...
# 8246     "tiros vindos do helicóptero da polícia perfuraram o asfalto."  "um menino morreu com um tiro na...
# 8259     de manhã teve uma operação na maré, a polícia tava de helicóptero dando tiro pra baixo, acertara...
# 8263     intervenção "salvando vidas", "sentimento de segurança transborda" aqui na maré. "muito bom" ouv...
# 8266     14 anos, a caminho da escola, com uniforme do colégio, com tiro vindo de helicóptero da polícia....
# 8280     bizarro o que aconteceu na maré hoje! buracos no asfalto de tiros de helicóptero, crianças nas e...
# 8283     polícia civil e exército realizam ação na maré espalhando terror e deixando mortos: 6 pessoas mo...
# 8285     não tem nada que justifique o mesmo helicóptero disparar tiros próximos a uma escola. o racismo ...
# 8289     não tem nada que justifique um helicóptero disparar tiros próximos a uma escola. a não ser o pró...
# 8294     a pm tá largando o aço na maré. o helicóptero simplesmente tá dando tiro pra baixo. o terror nas...
# 8295     pra vocês que falam " população negra não chega lá pq não quer pipipipopopo"  a criança na escol...
# 8296     fizeram o caralho da operação no horário que as crianças estão na escola  mano, vai se fuder por...
# 8330     tnc mano, pra que isso helicóptero dando tiro pra caralho pra baixo, porra cheio de gente na rua...
# 8363     esses policia e mt covarde msm horário de escola várias gente na rua e eles dando tiro de cima d...
# 8377     eles estão do helicóptero mandando tiro aqui pra baixo, não querem saber se tem morador na rua, ...
# 8396                         da a hr de ir p escola começa tiro, vem helicóptero, viatura..pq te amo pavuna?
# 8415     helicóptero, gritos, tiros ... mais um dia em que a insegurança pública se mostra eficaz. mais u...
# 8431     papo de que tiros estão vindo do helicóptero. cuidado aí morador. quem tá saindo pra ir a escola...
# 8474     praça seca amanhece com tiros, helicóptero e os caralho. mais um dia que meu filho não vai pra e...
# 8638     obrigado matheusa agora todos foram acordados com tiro e helicóptero, ninguém vai a escola e nin...
# 8669                       tiro p crl, e tem um helicóptero por aqui, se tiver na escola, vem p casa agr nao
# 8724                               helicóptero pela área uma hora dessa kkkmk se dar tiro nao vou pra escola
# 9389     atirando contra uma escola? isso é mentira, nenhum tiro atingiu a escola. a aeronave estava sobr...
# 9391     "alunos afirmam que helicóptero da polícia civil atirou em escola na maré, zona norte do rio des...
# 9392     desde cedo houve relatos de intenso tiroteio. vídeos nas redes sociais mostram aeronave dando ra...
# 9393     ele estava em cima da escola,mas pela posição nao parecia ser o alvo. as cápsulas não caem onde ...
# 9427     esta escola não é uma escola publica. cujo projeto de predio é de facil reconhecimento por quem ...
# 9432     já vi muitas incursões policiais na comunidade do são carlos. sempre são em horário escolar, usa...
# 9435     enquanto isso, na maré, a situação continua a mesma: caveirão voador atirando em morador, crianç...
# 9568     é usada uma aeronave pra "proteção de população e policiais", só que são encontrados 29 tiros di...
# 9694     hoje, do nada passou um águia pela escola, besha, tomei o susto. imagina ele dando tiro ? deus m...
# 9695     a professora tentando dar aula e começa operação na favela, o águia acerta vários tiros na escol...
# 9745     incrível cara 🤔 águia vem, da tiro a esmo, não quer saber se tem gente indo trabalhar, criança i...
# 9750     inúmeras vezes são em horários onde crianças estão indo pra escola e os moradores indo trabalhar...
# 9774     quando teu filho estiver na escola escola e o águia estiver dando tiro na escola dele ou jogando...
# 9780     mano e esse foto q tá rolando no zap das crianças tudo chorando na escola e esse fdp com o águia...
# 9802                                                                 e po aguia em cima da escola dando tiro
# 9803     ta que é pra denunciar já sabemos, mas quem ? os bandidos ou a policia que chega na favela em ho...
# 9808     como ir pra escola se esse águia está dando tiro igual um pinto no lixo pra tudo quanto é lado a...
# 9909     mano se eles derem tiro de .50 eles derruba o aguia e vale lembrar q a 99% de quem mora em favel...
# 9931     um domingo, fazendo um almoço no quintal/laje, com as crianças brincando na rua e do nada entrar...
# 9938     eu acho que eles tinham que chegar na tranquilidade, não com águia dando tiro pra tudo que é lad...
# 9944     só quem mora em favela sabe oque é isso , 6:30 da manhã águia dando tiro pra todo lado ,com cria...
# 9976     horário de trabalhador sai estudando ir a escola. esse aguia dando tiro a esmo na comunidade..😠😠😠😤😤
# 10159    hora d trabalhador ir trabalhar crianças ir pra escola eles vem com águia baixinho dando varios ...
# 10161                         águia, tiro e eu tendo quer ir pra escola por causa de trabalho e prova 😣😣😣😣🤙🏾
# 10192    "moradores denunciam que o helicóptero da polícia atirou do alto no horário em que as crianças s...
# 10193    moradores denunciam que o helicóptero da polícia atirou do alto no horário em que as crianças sa...
# 10194    moradores denunciam que o helicóptero da polícia atirou do alto no horário em que as crianças sa...
# 10196    ainda sobre a maré, hoje:  "eu estava saindo para trabalhar e nesse mesmo horário várias criança...
# 10197    + 8 mortes pela policia no rj  "eu estava saindo para trabalhar e nesse mesmo horário várias cri...
# 10236    incrível a imprudência policial do estado do rio de janeiro, cambada de fdp tem criança saindo d...
# 10237                                  cheio de criança vindo da escola e esse águia dando tiro, mó parada 😡
# 10248    se a operação é no morro do borel não vejo necessidade do águia passa aqui no morro dando tiro ,...
# 10251    é um absurdo o descaso com a comunidade o águia chega atirando na hora que as crianças estão sai...
# 10274    tiros deixam oito feridos em escola de suzano  o corpo de bombeiros foi acionado para atender a ...
# 10300            tnc desse governador, dar tiro do águia é mole.. várias crianças voltando da escola tnc 🤬🤬🤬
# 10347    aguia de ouro tentou dar uma lacradinha no ensaio técnico dessa semana (sexta se não me engano) ...
# 10348    a crítica política da águia de ouro é mais um tiro no pé dessa escola de samba que logo logo vai...
# 10463                                                        eu dá escola hoje vi os cana joga tiro do águia
# 10583    águia deu tiro p dentro da casa da minha tia pq um fdp invadiu lá p se esconder, mano e se pega ...
# 10643    essas porra ficam falando que o povo de favela não estuda porque não quer pipipopo   sendo que a...
# Name: tweet, dtype: object

# %%
def tokenization_s(sentences): # same can be achieved for words tokens
    s_new = []
    for sent in (sentences[:][0]): #For NumpY = sentences[:]
        s_token = sent_tokenize(sent)
        if s_token != '':
            s_new.append(s_token)
    return s_new

# %%
def preprocess(text):
    clean_data = []
    for x in (text[:][0]): #this is Df_pd for Df_np (text[:])
       # new_text = re.sub('<.*?>', '', x)   # remove HTML tags
        new_text = re.sub(r'[^\w\s]', '', x) # remove punc.
       # new_text = re.sub(r'\d+','',new_text)# remove numbers
        new_text = new_text.lower() # lower case, .upper() for upper          
        if new_text != '':
            clean_data.append(new_text)
    return clean_data

# %%
def tokenization_w(words):
    w_new = []
    for w in (words[:][0]):  # for NumPy = words[:]
        w_token = word_tokenize(w)
        if w_token != '':
            w_new.append(w_token)
    return w_new

# %%
snowball = SnowballStemmer(language = 'portuguese')
def stemming(words):
    new = []
    stem_words = [snowball.stem(x) for x in (words[:][0])]
    new.append(stem_words)
    return new

# %%
msgs = base['tweet'].astype(str)

# %%
#nltk.word_tokenize(base.tweet)

# %%
stopwords = nltk.corpus.stopwords.words('portuguese')
stopwords_en = nltk.corpus.stopwords.words('english')
# Define palavras a serem excluídas
newStopWords = ['lula','http','3r6nsl','u200d','helicoptero','policia',
                'aeronave','ly','tb','tche', 'pra', '…','cv43sn','gate21','xa0','tinyurl',
                'helicóptero','durante','aguia','bit','https','fu','ahh','br','tiro',
                'bit','favela','sido','cara','cv43sn\'','enquanto', 'pic', 'twitter', 'www', 'ser'
               'ver','suzano','tipo','xa0\'','bom','bolivia','anti','diz','xa0helicoptero','apos','dois',
                'list','rio','da','em','quem','por','na','mas','ja','era','para','mais','se','nao','do',
                'que','de','ou','com','teria','sempre','outro','ao','os','duas','at','uma','um',
                'tiros','tiro','disparo','helicoptero','q','ta','pq','html','01','2011','tá','ig_twitter_share','uns']

# STOPWORDS = nltk.corpus.stopwords.words('portuguese')

stopwords.extend(newStopWords)
stopwords.extend(stopwords_en)
len(stopwords)
# Out:
# 469

# %%
# Topic model com LDA
from sklearn.decomposition import NMF
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf_vect = TfidfVectorizer(max_df=0.8, min_df=2, stop_words= stopwords)
doc_term_matrix = tfidf_vect.fit_transform(base.tweet.values.astype('U'))

nmf = NMF(n_components=3, random_state=42)
nmf.fit(doc_term_matrix )

for i,topic in enumerate(nmf.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names()[i] for i in topic.argsort()[-30:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['desse', 'cana', 'alto', 'acordei', 'porra', 'voando', 'tão', 'tava', 'dessa', 'gente', 'morro', 'mané', 'hora', 'nada', 'baixinho', 'rasante', 'caralho', 'aqui', 'crlh', 'mano', 'mt', 'passou', 'vários', 'deus', 'crl', 'passando', 'cima', 'baixo', 'águia', 'dando']
#
#
# Top 10 words for topic #1:
# ['operação', 'globonews', 'instagram', 'igshid', 'caiu', 'guanabara', 'civil', 'ghtml', 'rj', 'imagens', 'pm', 'fbclid', 'rede', 'utm_campaign', 'utm_medium', 'desktop', 'chuvas', 'chuva', 'facebook', 'share', 'bar', 'guarda', 'utm_source', 'noticia', 'janeiro', 'g1', 'morro', 'mineira', 'atingido', 'globo']
#
#
# Top 10 words for topic #2:
# ['atirando', 'morador', 'vc', 'deus', 'som', 'rua', 'lá', 'perto', 'tudo', 'escola', 'ouvi', 'ser', 'gente', 'manhã', 'hoje', 'status', 'cima', 'nada', 'acordar', 'dar', 'agora', 'operação', 'vai', 'sobrevoando', 'casa', 'polícia', 'acordei', 'dia', 'aqui', 'barulho']

# %%
#from sklearn.decomposition import LatentDirichletAllocation

#LDA = LatentDirichletAllocation(n_components=5, random_state=42)
#LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(batch_size=128, doc_topic_prior=None,
#                           evaluate_every=-1, learning_decay=0.7,
#                           learning_method='batch', learning_offset=10.0,
#                           max_doc_update_iter=100, max_iter=10,
#                           mean_change_tol=0.001, n_components=5, n_jobs=None,
#                           perp_tol=0.1, random_state=42, topic_word_prior=None,
#                           total_samples=1000000.0, verbose=0)

# %%
#from sklearn.feature_extraction.text import CountVectorizer

#count_vect = CountVectorizer(max_df=0.8, min_df=2, stop_words= stopwords)
#doc_term_matrix = count_vect.fit_transform(base.tweet.values.astype('U'))

#doc_term_matrix

# %%
# Remove palavras comuns do dicionário padrão
tweets = [[word for word in tweet_words if not word in stopwords]
              for tweet_words in msgs]

# %%
words_in_tweet = [tweet.lower().split() for tweet in base.tweet]

# %%
words_in_tweet
# Out:
# [['em',
#   'julho,',
#   'consegui,',
#   'depois',
#   'de',
#   'um',
#   'ano',
#   'de',
#   'pedidos',
#   'e',
#   'recursos',
#   'via',
#   'lei',
#   'de',
#   'acesso',
#   'à',
#   'informação,',
#   'publicar',
#   'dados',
#   'sobre',
#   'uso',
#   'do',
#   'helicóptero',
#   'da',
#   'polícia',
#   'civil,',
#   'o',
#   'caveirão',
#   'aéreo,',
#   'em',
#   'operações',
#   'em',
#   'favelas.',
#   'https://extra.globo.com/casos-de-policia/rio-teve-operacoes-com-caveirao-voador-cada-quatro-dias-em-2018-23790068.html',
#   '…'],
#  ['esse',
#   'caveirao',
#   'aéreo',
#   'praticamente',
#   'na',
#   'minha',
#   'janela',
#   '🙄',
#   'eu',
#   'hein,',
#   'acorda',
#   'assim😡😡😡'],
#  ['canhoto:',
#   'adriano',
#   'destro:',
#   'pet',
#   'finalizador:',
#   'renato',
#   'abreu',
#   'maestro:',
#   'er7',
#   'força:',
#   'berrio',
#   'velocidade:',
#   'bruno',
#   'henrique',
#   'passe:',
#   'arrascaeta',
#   'drible:',
#   'felipe',
#   'jogo',
#   'aéreo:',
#   'souza',
#   'caveirao',
#   'https://twitter.com/joaotavaresrj/status/1190024240747163654',
#   '…'],
#  ['#bdrj',
#   'para',
#   'esses',
#   'bandidos',
#   'no',
#   'alto',
#   'do',
#   'morro',
#   'merecem',
#   'um',
#   'caveirão',
#   'aéreo.',
#   'helicóptero',
#   'mandando',
#   'bala',
#   'neles',
#   'e',
#   'nos',
#   'amiguinhos.',
#   'ah',
#   'mas',
#   'vcs',
#   'defendem',
#   'bandidos',
#   'né!',
#   'esqueci',
#   'que',
#   'não',
#   'gostam',
#   'do',
#   'helicóptero',
#   'nas',
#   'operações!'],
#  ['patrulheiro',
#   'de',
#   'assalto',
#   'aéreo',
#   'picareta',
#   'squeak',
#   'picareta',
#   'flamingo',
#   'rosa',
#   'emote',
#   'andando',
#   'e',
#   'assobiando',
#   'nog',
#   'ops',
#   'honor',
#   'guard',
#   'rogue',
#   'spider',
#   'knight',
#   'frozen',
#   'glow',
#   'caveirão',
#   'emote',
#   'cabaré',
#   'e',
#   'country',
#   'rubi',
#   'infiltrador',
#   'anjo',
#   'rodeio',
#   'de',
#   'foguetes',
#   'essa',
#   'é',
#   'minha',
#   'lista.n',
#   'acaba',
#   'por',
#   'aq'],
#  ['eu',
#   'acho',
#   'que',
#   'se',
#   'eu',
#   'pago',
#   'um',
#   'festival,',
#   'chego',
#   'lá',
#   'e',
#   'tem',
#   'um',
#   'palco',
#   'favela',
#   'que',
#   'imita',
#   'barulho',
#   'de',
#   'caveirao',
#   'aereo,',
#   'não',
#   'tem',
#   'dinheiro',
#   'gasto',
#   'certo,',
#   'eu',
#   'meto',
#   'o',
#   'pé',
#   'na',
#   'hora'],
#  ['e',
#   'você',
#   'que',
#   'gasta',
#   '6',
#   'milhões',
#   'em',
#   'um',
#   'caveirão',
#   'aéreo,',
#   'pra',
#   'metralhar',
#   'pessoas',
#   'inocentes',
#   'só',
#   'pela',
#   'cor',
#   'de',
#   'sua',
#   'pele',
#   'e',
#   'o',
#   'bairro',
#   'onde',
#   'vivem...',
#   'lamentável',
#   'é',
#   'as',
#   'pessoas',
#   'não',
#   'perceberem',
#   'quem',
#   'são',
#   'os',
#   'verdadeiros',
#   'genocidas'],
#  ['ou',
#   'a',
#   'gente',
#   'muda',
#   'essa',
#   'lógica',
#   'de',
#   'combate',
#   'ao',
#   'tráfico',
#   'de',
#   'drogas',
#   'e',
#   'armas',
#   'ou',
#   'mais',
#   'inocentes',
#   'e',
#   'operadores',
#   'do',
#   'estado',
#   'irão',
#   'morrer.',
#   'modernamente,',
#   'não',
#   'se',
#   'combate',
#   'o',
#   'tráfico',
#   'com',
#   'homens',
#   'de',
#   'fuzil,',
#   'caveirão',
#   'aéreo',
#   'e',
#   'tanque',
#   'de',
#   'guerra',
#   'na',
#   'favela.',
#   'se',
#   'combate',
#   'mapeando',
#   'o',
#   'caminho',
#   'do',
#   'dinheiro!'],
#  ['estudantes',
#   'da',
#   'escola',
#   'municipal',
#   'do',
#   'complexo',
#   'da',
#   'maré',
#   'agachados',
#   'sob',
#   'ataque',
#   'do',
#   'caveirão',
#   'aéreo'],
#  ['o',
#   'caveirão',
#   'aéreo',
#   'dá',
#   'rasantes',
#   'no',
#   'mirante',
#   'do',
#   'leblon',
#   'e',
#   'na',
#   'pedra',
#   'do',
#   'arpoador',
#   'e',
#   'a',
#   'galera',
#   'aplaude.',
#   'não',
#   'há',
#   'previsão',
#   'de',
#   'fim',
#   'para',
#   'essa',
#   'barbárie.'],
#  ['imagina',
#   'sua',
#   'mãe',
#   'saindo',
#   'pra',
#   'trabalhar',
#   'de',
#   'manhã',
#   'cedo',
#   'os',
#   'canas',
#   'faz',
#   'operação',
#   'na',
#   'favela,',
#   'aonde',
#   'eu',
#   'moro',
#   'os',
#   'canas',
#   'vem',
#   'de',
#   'caveirao',
#   'aéreo',
#   'dando',
#   'tiro',
#   'pra',
#   'baixo',
#   'ele',
#   'não',
#   'sabe',
#   'em',
#   'quem',
#   'tá',
#   'dando',
#   'tiro',
#   'as',
#   'vezes',
#   'acerta',
#   'morador',
#   'e',
#   'criança',
#   'que',
#   'não',
#   'tem',
#   'nada',
#   'haver',
#   'e',
#   'muitas',
#   'das',
#   'vezes',
#   'tá',
#   'dentro',
#   'de',
#   'cs',
#   'tb'],
#  ['#repost',
#   '@bertjoi',
#   'with',
#   'get_repost',
#   '・・・',
#   'agatha.',
#   '8',
#   'anos.',
#   'tiro',
#   'nas',
#   'costas.',
#   'estava',
#   'dentro',
#   'da',
#   'kombi/lotação.',
#   'a',
#   'caminho',
#   'de',
#   'casa.',
#   'com',
#   'sua',
#   'família.',
#   'na',
#   'mesma',
#   'semana,',
#   'helicóptero',
#   'ou',
#   'caveirão',
#   'aéreo,',
#   'sobrevoa',
#   'escola.',
#   'atirando.…',
#   'https://www.instagram.com/p/b2rvpkta99u/?igshid=ypq1z8dc2hgk',
#   '…'],
#  ['daqui',
#   'a',
#   'pouco',
#   'estouram',
#   'esse',
#   'caveirao',
#   'aéreo',
#   'e',
#   'o',
#   'witzel',
#   'bobão',
#   'vai',
#   'magoar',
#   'https://twitter.com/quebrandootabu/status/1174450525909262337',
#   '…'],
#  ['#witzelassassino.',
#   'parem',
#   'de',
#   'nos',
#   'matar!',
#   'abaixo',
#   'criançasda',
#   'escolamunicipal',
#   'no',
#   'pinheiro,',
#   'complexo',
#   'da',
#   'maré,',
#   'sobre',
#   'tiros',
#   'do',
#   'caveirão',
#   'aéreo.',
#   'pic.twitter.com/eawukbqd5r'],
#  ['nas',
#   'escolas',
#   'que',
#   'foram',
#   'alvos',
#   'do',
#   'caveirão',
#   'aéreo,',
#   'funcionários',
#   'ainda',
#   'estão',
#   'com',
#   'medo.',
#   'a',
#   'maioria',
#   'se',
#   'mantem',
#   'em',
#   'silêncio',
#   'por',
#   'receio',
#   'de',
#   'represálias',
#   'e',
#   'comentaram',
#   'sobre',
#   'risco',
#   'de',
#   'exoneração.',
#   'a',
#   'política',
#   'é',
#   'não',
#   'dar',
#   'entrevista',
#   'sem',
#   'autorização.',
#   '#witzelassassino',
#   '#aculpaédowitzel'],
#  ['mais',
#   'um',
#   'dia',
#   'perdido.',
#   'estudar',
#   'pra',
#   'que?',
#   'trabalhar',
#   'pra',
#   'que?',
#   'caveirão',
#   'aéreo',
#   'e',
#   'terrestre.',
#   'e',
#   'a',
#   'favela',
#   'sangra',
#   'mais',
#   'uma',
#   'vez.',
#   'que',
#   'tristeza!',
#   '😔',
#   'pic.twitter.com/nhkqylowsm'],
#  ['caveirão',
#   'aéreo',
#   'voltou.',
#   'atividade',
#   'morador!',
#   'tomem',
#   'cuidado',
#   'com',
#   'suas',
#   'crianças',
#   'em',
#   'casa,',
#   'já',
#   'que',
#   'o',
#   'estado',
#   'impede',
#   'que',
#   'as',
#   'aulas',
#   'aconteçam.',
#   'é',
#   'violenta',
#   'e',
#   'irresponsável',
#   'essas',
#   'operações',
#   'que',
#   'não',
#   'constroem',
#   'nada!',
#   'jovens',
#   'foram',
#   'mortos',
#   'hoje,',
#   'pessoas',
#   'foram',
#   'baleadas.',
#   'tenhamos',
#   'cautela.',
#   '–',
#   'at',
#   'complexo',
#   'do',
#   'alemão'],
#  ['denúncia',
#   'recebida',
#   'nas',
#   'redes',
#   'do',
#   '@vozdacomunidade',
#   'durante',
#   'a',
#   'operação',
#   'que',
#   'acontece',
#   'desde',
#   'o',
#   'início',
#   'da',
#   'manhã',
#   'de',
#   'hoje',
#   'no',
#   'complexo',
#   'do',
#   'alemão,',
#   'que',
#   'conta',
#   'com',
#   'o',
#   'apoio',
#   'do',
#   'caveirão',
#   'terrestre',
#   'e',
#   'o',
#   'aéreo.',
#   'pic.twitter.com/2ofhzt4jdn'],
#  ['nós,',
#   'moradores',
#   'minimamente',
#   'alertamos',
#   'em',
#   'dias',
#   'de',
#   'operações',
#   'policiais:',
#   'atividade',
#   'morador,',
#   'não',
#   'levem',
#   'suas',
#   'crianças',
#   'para',
#   'a',
#   'escola.',
#   'não',
#   'se',
#   'arrisquem',
#   'nas',
#   'ruas.',
#   'protejam-se',
#   'dentro',
#   'de',
#   'casa.',
#   'o',
#   'estado:',
#   'envia',
#   'o',
#   'caveirão',
#   'aéreo',
#   'e',
#   'atira',
#   'de',
#   'fuzil',
#   'sobre',
#   'as',
#   'casas',
#   'nas',
#   'favelas.',
#   '#aculpaédowitzel',
#   '–',
#   'at',
#   'complexo',
#   'do',
#   'alemão'],
#  ['[⚠️',
#   'caveirão',
#   'aéreo',
#   'no',
#   'cpx',
#   '⚠️]',
#   'muita',
#   'atenção',
#   'ao',
#   'sairem',
#   'de',
#   'suas',
#   'casas.',
#   'tomem',
#   'muito',
#   'cuidado',
#   'com',
#   'as',
#   'crianças.',
#   'helicóptero',
#   'da',
#   'pm',
#   'está',
#   'dando',
#   'rasantes',
#   'pelo',
#   'complexo',
#   'do',
#   'alemão.',
#   'politica',
#   'publica',
#   'do',
#   'terror',
#   'e',
#   'do',
#   'medo',
#   'por',
#   'parte',
#   'so',
#   'sr.',
#   '@wilsonwitzel.',
#   '📸',
#   '@eufbento',
#   '|',
#   '@cpapo_reto',
#   '📢💬',
#   'pic.twitter.com/gscongderp',
#   '–',
#   'at',
#   'complexo',
#   'do',
#   'alemão'],
#  ['pra',
#   'vc',
#   'que',
#   'tá',
#   'querendo',
#   'mídia',
#   'não',
#   'deve',
#   'saber',
#   'que',
#   'quem',
#   'tá',
#   'recebendo',
#   'tiro',
#   'é',
#   'o',
#   'caveirao',
#   'aéreo',
#   'o',
#   'msm',
#   'que',
#   'meu',
#   'pai',
#   'trabalha!',
#   'e',
#   'o',
#   'barulho',
#   'que',
#   'vc',
#   'tá',
#   'escutando',
#   'vindo',
#   'do',
#   'helicóptero',
#   'são',
#   'as',
#   'pás',
#   'dele',
#   'batendo.',
#   'esse',
#   'é',
#   'o',
#   'típico',
#   'barulho',
#   'do',
#   'hzao!',
#   'midiazinha',
#   'boba',
#   '🤷🏽\u200d♂️',
#   'https://twitter.com/paatty14f/status/1173899230303477761',
#   '…'],
#  ['o',
#   'jacarezinho',
#   'amanheceu',
#   'com',
#   'o',
#   'caveirão',
#   'aéreo',
#   'atirando',
#   'arbitrariamente',
#   'sobre',
#   'as',
#   'casas.',
#   'já',
#   'são',
#   'dois',
#   'dias',
#   'de',
#   'operação,',
#   'com',
#   'os',
#   'moradores',
#   'presos',
#   'dentro',
#   'de',
#   'suas',
#   'casas.',
#   'a',
#   'política',
#   'da',
#   'barbárie',
#   'nas',
#   'favelas',
#   'continua',
#   'a',
#   'todo',
#   'vapor.',
#   'isso',
#   'tem',
#   'nome:',
#   'terrorismo',
#   'de',
#   'estado!'],
#  ['sim',
#   'amiga,',
#   'essa',
#   'porra',
#   'virou',
#   'um',
#   'caveirao',
#   'aéreo',
#   'e',
#   'só',
#   'tem',
#   'um',
#   'objetivo',
#   'que',
#   'eh',
#   'matar',
#   'preto',
#   'pobre',
#   'e',
#   'favelado'],
#  ['limitar',
#   'espaço',
#   'aéreo',
#   'para',
#   'a',
#   'grobo',
#   'não',
#   'proteger',
#   'os',
#   'vítimas',
#   'da',
#   'sociedade,',
#   'caveirão',
#   'aéreo',
#   'e',
#   'saaaalll.'],
#  ['faltou',
#   'o',
#   'caveirão',
#   'aéreo',
#   'pra',
#   'limpar',
#   'parte',
#   'da',
#   'sujeira',
#   'que',
#   'fugia',
#   'pelo',
#   'mato.'],
#  ['quando',
#   'a',
#   'pm',
#   'for',
#   'fazer',
#   'operação',
#   'em',
#   'favela',
#   'tem',
#   'que',
#   'fechar',
#   'o',
#   'espaço',
#   'aéreo',
#   'para',
#   'helicópteros.',
#   'principalmente',
#   'para',
#   'o',
#   'da',
#   'rede',
#   'esgoto.',
#   'só',
#   'caveirão',
#   'no',
#   'ar.'],
#  ['📌',
#   'cidade',
#   'de',
#   'deus',
#   '|',
#   '🚨caveirão',
#   'aéreo',
#   'em',
#   'operação',
#   'na',
#   'cdd',
#   '.',
#   '.',
#   '📝',
#   '"recebemos',
#   'imagens',
#   'e',
#   'mais',
#   'cedo,',
#   'do',
#   'caveirão',
#   'aéreo',
#   'em',
#   'operação',
#   'na',
#   'cdd.',
#   'a',
#   'operação',
#   'da',
#   'polícia',
#   'militar',
#   'continua',
#   'na',
#   'área',
#   'de',
#   'mata',
#   'para',
#   'onde',
#   'os',
#   'marginais…',
#   'https://www.instagram.com/p/b2rqcgtgdqt/?igshid=8ffpc1esnfyi',
#   '…'],
#  ['a',
#   'pm',
#   'segue',
#   'a',
#   'rotina',
#   'de',
#   'operações',
#   'na',
#   'cdd',
#   'pelo',
#   'terceiro',
#   'dia',
#   'seguido.',
#   'já',
#   'são',
#   'três',
#   'dias',
#   'sem',
#   'aula',
#   'para',
#   'as',
#   'crianças',
#   'e',
#   'de',
#   'terror',
#   'para',
#   'suas',
#   'famílias.',
#   'o',
#   'governo',
#   'witzel',
#   'continua',
#   'sua',
#   'jornada',
#   'de',
#   'confrontos',
#   'ostensivos,',
#   'de',
#   'caveirão',
#   'aéreo,',
#   'de',
#   'naturalização',
#   'da',
#   'barbárie.'],
#  ['manooo',
#   'o',
#   'caveirão',
#   'aéreo',
#   'tremeu',
#   'o',
#   'ap',
#   'na',
#   'cdd',
#   'hj,',
#   'foi',
#   'clima',
#   'tensoooo',
#   'd+'],
#  ['bem,',
#   'eu',
#   'estava',
#   'na',
#   'praia',
#   'com',
#   'uma',
#   'turma',
#   'grande',
#   'de',
#   'turistas',
#   'e',
#   'todos',
#   'ficaram',
#   'horrorizados',
#   'com',
#   'o',
#   'rasante',
#   'do',
#   'caveirão',
#   'aéreo',
#   'e',
#   'seus',
#   'ridículos',
#   'policiais',
#   'exibidos.'],
#  ['caveirao', 'aéreo', 'pic.twitter.com/rcbmemwkno'],
#  ['nova',
#   'escola,',
#   'por',
#   '@leandrobeguoci',
#   '|',
#   'com',
#   "'caveirão",
#   "aéreo',",
#   'perdemos',
#   'a',
#   'sensibilidade',
#   'para',
#   'o',
#   'horror',
#   'cotidiano',
#   'https://www1.folha.uol.com.br/colunas/novaescola/2019/08/as-criancas-da-mare-serao-as-nossas-ultimas-testemunhas.shtml?utm_source=twitter&utm_medium=social&utm_campaign=twfolha',
#   '…'],
#  ['mas',
#   'o',
#   'caveirão',
#   'aéreo',
#   'só',
#   'usa',
#   'guarda-chuva',
#   'e',
#   'furadeira,',
#   'igual',
#   'os',
#   'traficantes.',
#   'não',
#   'temam',
#   'defensores',
#   'de',
#   'bandidos!'],
#  ['colunista:',
#   'nova',
#   'escola',
#   '|',
#   'folha',
#   '-',
#   'caveirao',
#   'aéreo',
#   'https://www1.folha.uol.com.br/colunas/novaescola/',
#   '…'],
#  ['nova',
#   'escola',
#   '|',
#   'as',
#   'crianças',
#   'da',
#   'maré',
#   'serão',
#   'as',
#   'nossas',
#   'últimas',
#   'testemunhas;',
#   'com',
#   "'caveirão",
#   "aéreo',",
#   'perdemos',
#   'a',
#   'sensibilidade',
#   'para',
#   'o',
#   'horror',
#   'cotidiano',
#   '(por',
#   '@leandrobeguoci)',
#   'https://www1.folha.uol.com.br/colunas/novaescola/2019/08/as-criancas-da-mare-serao-as-nossas-ultimas-testemunhas.shtml?utm_source=twitter&utm_medium=social&utm_campaign=twfolha',
#   '…'],
#  ['eu',
#   'quase',
#   'botando',
#   'o',
#   'pé',
#   'pra',
#   'fora',
#   'de',
#   'casa',
#   'pra',
#   'ir',
#   'trabalhar,',
#   'ouço',
#   'o',
#   'caveirão',
#   'aéreo',
#   'tremendo',
#   'as',
#   'portas',
#   'e',
#   'janelas',
#   'da',
#   'minha',
#   'casa.',
#   'pqppppppp'],
#  ['atualizando',
#   '6h43',
#   'operação',
#   'segue',
#   'firme,',
#   'caveirão',
#   'terrestre',
#   'e',
#   'aéreo',
#   'baqueando!',
#   'conjunto',
#   'esperança,',
#   'salsa',
#   'e',
#   'merengue,',
#   'vila',
#   'do',
#   'joão,',
#   'pinheiro',
#   'atividade',
#   'geral!',
#   'não',
#   'saíam',
#   'gente!',
#   'morro',
#   'do',
#   'timbau,',
#   'fogo',
#   'cruzado,',
#   'nova',
#   'maré…',
#   'https://www.instagram.com/p/b0qdrdjapoz/?igshid=cz07tqn0jgjv',
#   '…'],
#  ['eu',
#   'deveria',
#   'encontrar',
#   'o',
#   'meu',
#   'médico',
#   'pessoal',
#   'hoje.',
#   'não',
#   'irei',
#   'porque',
#   'a',
#   'pmerj',
#   'resolveu',
#   'praticar',
#   'tiro',
#   'na',
#   'maré',
#   'hoje.',
#   'obrigada',
#   '@wilsonwitzel!',
#   'adorei',
#   'o',
#   'despertador',
#   'modo',
#   'caveirão',
#   'aéreo!',
#   '#marévive',
#   '#afavelaresiste'],
#  ['crimes',
#   'do',
#   '"caveirão',
#   'aéreo"',
#   '//',
#   'mpf',
#   'quer',
#   'investigar',
#   'crimes',
#   'a',
#   'bordo',
#   'de',
#   'helicópteros',
#   'em',
#   'ação',
#   'policial',
#   'no',
#   'rio',
#   '|',
#   'https://www.revistaforum.com.br/mpf-quer-investigar-crimes-a-bordo-de-helicopteros-em-acao-policial-no-rio/#.xqlui0vj_hg.twitter',
#   '…'],
#  ['o',
#   'rj',
#   'trasportao',
#   'contrabando',
#   'no',
#   'caveirao',
#   'aqui',
#   'taxi',
#   'aereo',
#   'no',
#   'helicopetero',
#   'da',
#   'policiia',
#   'piiada',
#   'sabe',
#   'por',
#   'que',
#   'isso',
#   'acontece',
#   'falta',
#   'de',
#   'puniçao'],
#  ['@bomdiarj',
#   '@bdrj',
#   '#bdrj',
#   'possivel',
#   'operaçao',
#   'da',
#   'policia',
#   'em',
#   'duque',
#   'de',
#   'caxias,',
#   'no',
#   'complexo',
#   'da',
#   'mangueirinha.',
#   'com',
#   'caveirão',
#   'aéreo.'],
#  ['nesta',
#   'coleta',
#   'está',
#   'o',
#   'caso',
#   'do',
#   '"caveirão',
#   'aéreo"',
#   'do',
#   'governador',
#   '@wilsonwitzel',
#   '?'],
#  ['governo',
#   'terrorista',
#   'ataca',
#   '+',
#   'uma',
#   'vez',
#   'a',
#   'favela',
#   'da',
#   'maré',
#   'com',
#   'caveirão',
#   'aéreo',
#   'e',
#   'terrestre.',
#   'deus',
#   'proteja',
#   'a',
#   'população',
#   'das',
#   'mão',
#   'desses',
#   'assassinos.',
#   'a',
#   'fascismo',
#   'produtor',
#   'do',
#   '#ódio',
#   'atacam',
#   'covardemente',
#   'se',
#   'preparando',
#   'p/eleições',
#   '2022',
#   'usando',
#   'corpos',
#   'humanos',
#   'como',
#   'alimento',
#   'a',
#   'esse',
#   'poder',
#   'pobre..😡'],
#  ['#acordamorador',
#   '"caveirão',
#   'aéreo"',
#   'do',
#   'governador',
#   'continua',
#   'aterrorizando',
#   'as',
#   'favelas',
#   'do',
#   'estado.',
#   'agora,',
#   'um',
#   'helicóptero',
#   'sobrevoa',
#   'o',
#   'complexo',
#   'da',
#   'maré',
#   'disparando',
#   'sobre',
#   'as',
#   'comunidades',
#   'do',
#   'parque',
#   'união,',
#   'nova',
#   'holanda',
#   'e',
#   'rubens',
#   'vaz,',
#   'segundo',
#   'relatos',
#   'de',
#   'moradores',
#   'sempre',
#   'em',
#   'horário',
#   'escolar',
#   '🤔'],
#  ['caveirão',
#   'aéreo',
#   'disparando',
#   'sibre',
#   'as',
#   'comunidades',
#   'https://twitter.com/danimontpsol/status/1128015881756467200',
#   '…'],
#  ['urgente!',
#   'o',
#   '"caveirão',
#   'aéreo"',
#   'do',
#   'governo',
#   'witzel',
#   'continua',
#   'aterrorizando',
#   'as',
#   'favelas',
#   'do',
#   'estado.',
#   'agora,',
#   'um',
#   'helicóptero',
#   'sobrevoa',
#   'o',
#   'complexo',
#   'da',
#   'maré',
#   'disparando',
#   'sobre',
#   'as',
#   'comunidades',
#   'do',
#   'parque',
#   'união,',
#   'nova',
#   'holanda',
#   'e',
#   'rubens',
#   'vaz,',
#   'segundo',
#   'relatos',
#   'de',
#   'moradores.',
#   'até',
#   'quando?!'],
#  ['e',
#   'as',
#   'políticas',
#   'de',
#   'segurança',
#   'pública',
#   'do',
#   'governo',
#   'witzel',
#   '-',
#   'em',
#   'acordo',
#   'com',
#   'a',
#   'do',
#   'governo',
#   'anterior',
#   '-',
#   'continua',
#   'agindo',
#   'de',
#   'forma',
#   'racista',
#   'e',
#   'violenta',
#   'nas',
#   'favelas.',
#   'caveirão',
#   'aéreo',
#   'atirando',
#   'à',
#   'esmo',
#   'na',
#   'maré.',
#   'população',
#   'acuada',
#   'e',
#   'sofrendo',
#   'violações',
#   'diversas',
#   'à',
#   'todo',
#   'tempo.'],
#  ['#urgente',
#   '15:55',
#   '-',
#   'clima',
#   'tenso',
#   'no',
#   'complexo',
#   'da',
#   'maré!!!',
#   'caveirão',
#   'aéreo',
#   'sobrevoando',
#   'a',
#   'área',
#   'e',
#   'atirando,',
#   'segundo',
#   'informações',
#   'de',
#   'moradores',
#   'da',
#   'região.'],
#  ['após',
#   'ação',
#   'de',
#   'witzel',
#   'no',
#   '“caveirão',
#   'aéreo”,',
#   'colégio',
#   'coloca',
#   'placa',
#   'no',
#   'teto:',
#   '“escola.',
#   'não',
#   'atire!”',
#   'https://www.diariodocentrodomundo.com.br/essencial/apos-acao-de-witzel-no-caveirao-aereo-colegio-coloca-placa-no-teto-escola-nao-atire/',
#   '…'],
#  ['após',
#   'ação',
#   'de',
#   'witzel',
#   'no',
#   '“caveirão',
#   'aéreo”,',
#   'colégio',
#   'coloca',
#   'placa',
#   'no',
#   'teto:',
#   '“escola.',
#   'não',
#   'atire!”',
#   'https://www.diariodocentrodomundo.com.br/essencial/apos-acao-de-witzel-no-caveirao-aereo-colegio-coloca-placa-no-teto-escola-nao-atire/',
#   '…'],
#  ['procuradores',
#   'e',
#   'defensores',
#   'federais',
#   'acusam',
#   'witzel',
#   'de',
#   'uso',
#   'ilegal',
#   'de',
#   '“caveirão',
#   'aéreo”',
#   'no',
#   'rio',
#   'https://www.diariodocentrodomundo.com.br/essencial/procuradores-e-defensores-federais-acusam-witzel-de-uso-ilegal-de-caveirao-aereo-no-rio/',
#   '…'],
#  ['procuradores',
#   'e',
#   'defensores',
#   'federais',
#   'acusam',
#   'witzel',
#   'de',
#   'uso',
#   'ilegal',
#   'de',
#   '“caveirão',
#   'aéreo”',
#   'no',
#   'rio',
#   'https://www.diariodocentrodomundo.com.br/essencial/procuradores-e-defensores-federais-acusam-witzel-de-uso-ilegal-de-caveirao-aereo-no-rio/',
#   '…'],
#  ['procuradores',
#   'e',
#   'defensores',
#   'federais',
#   'acusam',
#   'witzel',
#   'de',
#   'uso',
#   'ilegal',
#   'de',
#   '“caveirão',
#   'aéreo”',
#   'no',
#   'rio',
#   'https://www.diariodocentrodomundo.com.br/essencial/procuradores-e-defensores-federais-acusam-witzel-de-uso-ilegal-de-caveirao-aereo-no-rio/',
#   '…'],
#  ['despertador',
#   'de',
#   'favela',
#   'eh',
#   'caveirao',
#   'aereo',
#   'pic.twitter.com/mcrh4pw5he'],
#  ['bernardo',
#   'mello',
#   'franco:',
#   'o',
#   'governador',
#   'chuck',
#   'norris',
#   '-',
#   'wilson',
#   'witzel',
#   'embarcou',
#   'num',
#   '“caveirão',
#   'aéreo”',
#   'para',
#   'bancar',
#   'o',
#   'xerife',
#   'em',
#   'angra.',
#   'para',
#   'a',
#   'oab,',
#   'a',
#   'ação',
#   'desrespeitou',
#   'decreto',
#   'que',
#   'proíbe',
#   'atiradores',
#   'em',
#   'helicópteros',
#   'http://bit.ly/2yfpaz7',
#   'via',
#   '@conteudo_livre'],
#  ['bernardo',
#   'mello',
#   'franco:',
#   'o',
#   'governador',
#   'chuck',
#   'norris',
#   'wilson',
#   'witzel',
#   'embarcou',
#   'num',
#   '“caveirão',
#   'aéreo”',
#   'para',
#   'bancar',
#   'o',
#   'xerife',
#   'em',
#   'angra.',
#   'para',
#   'a',
#   'oab,',
#   'a',
#   'ação',
#   'desrespeitou',
#   'decreto',
#   'que',
#   'proíbe',
#   'atiradores',
#   'em',
#   'helicópteros',
#   'http://bit.ly/2yfpaz7'],
#  ['caveirão',
#   'aéreo',
#   'aterroriza',
#   'são',
#   'gonçalo',
#   'https://youtu.be/ekmyirxeejy',
#   'via',
#   '@youtube'],
#  ['quero',
#   'fazer',
#   'a',
#   'terapia',
#   'de',
#   'não',
#   'ter',
#   'o',
#   'blindado',
#   'terrestre',
#   '(caveirão)',
#   'ou',
#   'o',
#   'blindado',
#   'aéreo',
#   '(helicóptero)',
#   'passando',
#   'disparando',
#   'rajadas',
#   'de',
#   'grosso',
#   'calibre,',
#   'a',
#   'esmo,',
#   'na',
#   'localidade',
#   'meus',
#   'filhos,',
#   'filhas',
#   'e',
#   'eu',
#   'vivemos.',
#   '😓'],
#  ['[26/3',
#   '06:13]',
#   'velho:',
#   'acorda',
#   'seus',
#   'fdps',
#   '[26/3',
#   '06:13]',
#   'velho:',
#   'meter',
#   'bala',
#   '[26/3',
#   '06:14]',
#   'velho:',
#   'caveirao',
#   'aéreo',
#   '[26/3',
#   '06:14]',
#   'velho:',
#   'tá',
#   'na',
#   'área'],
#  ['armamento',
#   'encontrado',
#   'na',
#   'casa',
#   'do',
#   'pm',
#   'ronie',
#   'lessa.....e',
#   'governador',
#   'witzel',
#   'mandando',
#   'metralhar',
#   'as',
#   'favelas',
#   'dos',
#   'rio',
#   'de',
#   'janeiro',
#   'com',
#   'o',
#   'caveirão',
#   'aéreo.',
#   'pic.twitter.com/x1gutuact2'],
#  ['tenho',
#   'lido',
#   'o',
#   'jb,',
#   'e',
#   'parece',
#   'que',
#   'tem',
#   'sniper',
#   'em',
#   'manguinhos',
#   'e',
#   '"caveirão',
#   'aéreo"',
#   'no',
#   'alemão,',
#   'se',
#   'liguem.'],
#  ['governo',
#   'do',
#   'ww',
#   'colocando',
#   'o',
#   'caveirão',
#   'aéreo',
#   'em',
#   'ação',
#   'na',
#   'maré!',
#   'aeronaves',
#   'não',
#   'devem',
#   'ser',
#   'usadas',
#   'como',
#   'plataforma',
#   'de',
#   'tiro!',
#   'policiais',
#   'não',
#   'podem',
#   'atirar',
#   'a',
#   'esmo',
#   'contra',
#   'pessoas',
#   'na',
#   'favela!',
#   '#caveirãonão',
#   '#vidasnasfavelasimportam',
#   '#paremdenosmatar',
#   'https://twitter.com/redesdamare/status/1098614343783145475',
#   '…'],
#  ['acordar', 'com', 'o', 'caveirão', 'aéreo', 'bom', 'dia', 'privilegiadxs'],
#  ['é',
#   'nessas',
#   'horas',
#   'que',
#   'o',
#   'caveirao',
#   'aéreo',
#   'tinha',
#   'que',
#   'surpreender',
#   'largando',
#   'o',
#   'aço'],
#  ['"era',
#   'próximo',
#   'ao',
#   'meio',
#   'dia',
#   'de',
#   'domingo',
#   'quando',
#   'um',
#   'caveirão',
#   'aéreo',
#   'iniciou',
#   'os',
#   'disparos',
#   'em',
#   'direção',
#   'daqueles',
#   'que',
#   'corriam',
#   'no',
#   'estilo',
#   '’’salvem-se',
#   'quem',
#   'puder”.',
#   'toda',
#   'a',
#   'cena',
#   'foi',
#   'transmitida',
#   'ao',
#   'vivo',
#   'pela',
#   'tv',
#   'globo,',
#   'também',
#   'de',
#   'um',
#   'helicóptero,',
#   'enquanto',
#   'jornalistas',
#   'ocupavam',
#   'a',
#   'parte',
#   'baixa',
#   'da',
#   'favela"',
#   'https://twitter.com/vozdacomunidade/status/1067906187260252162',
#   '…'],
#  ['então',
#   'guerreiro!!',
#   'a',
#   'ideia',
#   'é',
#   'transmitir',
#   'os',
#   'abates',
#   'ao',
#   'vivo,',
#   'junto',
#   'com',
#   'o',
#   'café',
#   'da',
#   'manhã!!',
#   'a',
#   'partir',
#   'da',
#   'confirmação',
#   'do',
#   'globocop,',
#   'o',
#   'caveirão',
#   'aéreo',
#   'larga',
#   'o',
#   'aço!!',
#   'nosso',
#   'estado',
#   'limpo',
#   'e',
#   'sua',
#   'audiência',
#   'no',
#   'espaço!!',
#   'é',
#   'a',
#   'nova',
#   'era!!'],
#  ['#balançogeralrj',
#   'que',
#   'lado',
#   'ficou',
#   'em',
#   'vantagem',
#   'com',
#   'a',
#   'proibição',
#   'de',
#   'operações',
#   'policiais',
#   'com',
#   'o',
#   'caveirão',
#   'aéreo:',
#   'o',
#   'criminoso',
#   'ou',
#   'a',
#   'sociedade',
#   '?'],
#  ['sai',
#   'do',
#   'morro',
#   'e',
#   'minha',
#   'tia',
#   'me',
#   'ligou',
#   'falando',
#   'que',
#   '2',
#   'caveirão',
#   'aéreo',
#   'estava',
#   'rodeando',
#   'o',
#   'morro,',
#   'para',
#   'eu',
#   'ir',
#   'com',
#   'deus.',
#   '🙏'],
#  ['caveirão',
#   'aéreo,',
#   'não!',
#   'helicóptero',
#   'não',
#   'pode',
#   'ser',
#   'usado',
#   'como',
#   'plataforma',
#   'de',
#   'tiro',
#   'contra',
#   'a',
#   'população',
#   'favelada.',
#   '#tarcisionosbt',
#   '#debatesbtrio',
#   'pic.twitter.com/llw9pdwkl5'],
#  ['caveirao', 'aéreo', '😱'],
#  ['#notapúblicacndh',
#   '|em',
#   'nota',
#   'pública,',
#   'cndh',
#   'recomenda',
#   'banimento',
#   'do',
#   'caveirão',
#   'aéreo|',
#   'veja',
#   'a',
#   'nota',
#   'na',
#   'íntegra:',
#   'https://bit.ly/2pmi36r',
#   '#direitoshumanos',
#   '#participaçãopopular',
#   'pic.twitter.com/vcf33ifgsb'],
#  ['o',
#   'caveirao',
#   'aéreo',
#   'blindado',
#   'da',
#   'core',
#   'acaba',
#   'de',
#   'passar',
#   'voando',
#   'baixo',
#   'no',
#   'centro',
#   'rumo',
#   'a',
#   'alguma',
#   'operação'],
#  ['eu',
#   'moro',
#   'em',
#   'asfalto',
#   'relativamente',
#   'perto',
#   'de',
#   'dois',
#   'morros',
#   'e',
#   'tem',
#   'helicóptero',
#   'em',
#   'cima',
#   'da',
#   'minha',
#   'casa',
#   'total',
#   'mirando',
#   'pro',
#   'morro.',
#   'cara,',
#   'isso',
#   'é',
#   'desumano,',
#   'a',
#   'galera',
#   'que',
#   'mora',
#   'lá',
#   'estão',
#   'dormindo,',
#   'ou',
#   'tentando,',
#   'na',
#   'mira',
#   'de',
#   'caveirao',
#   'aéreo.',
#   'se',
#   'eu',
#   'to',
#   'sentindo',
#   'medo',
#   'imagina',
#   'eles.',
#   '#pmassassina'],
#  ['caveirao', 'aéreo', 'uma', 'hora', 'dessa', '🤦\u200d♀️'],
#  ['12h',
#   'de',
#   'operação',
#   'no',
#   'alemão.',
#   'pm,',
#   'civil',
#   'e',
#   'exército.',
#   'blindados,',
#   'caveirão',
#   'aéreo',
#   'e',
#   'muito',
#   'terror.',
#   'os',
#   'moradores',
#   'gritaram,',
#   'pediram',
#   'socorro.'],
#  ['moradores',
#   'do',
#   'complexo',
#   'do',
#   'lins',
#   'denunciam',
#   "'caveirão",
#   "aéreo'",
#   'atirando',
#   'de',
#   'cima',
#   'para',
#   'baixo',
#   'https://glo.bo/2ldmwgq'],
#  ['vocês',
#   'não',
#   'sabem',
#   'oque',
#   'é',
#   'dormir',
#   'com',
#   'medo',
#   'dos',
#   'tiros,',
#   'vcs',
#   'não',
#   'sabem',
#   'oque',
#   'é',
#   'olhar',
#   'da',
#   'sua',
#   'janela',
#   'e',
#   'ver',
#   'caveirão',
#   'aéreo',
#   'com',
#   'armas',
#   'gigantes',
#   'pra',
#   'fora,',
#   'vocês',
#   'não',
#   'sabem',
#   'oque',
#   'é',
#   'sair',
#   'pra',
#   'estudar',
#   'e',
#   'ser',
#   'parado',
#   'na',
#   'porta',
#   'da',
#   'sua',
#   'escola',
#   'por',
#   'viatura',
#   'revistando',
#   'geral',
#   'até',
#   'criança!!'],
#  ['o',
#   'marcos',
#   'que',
#   'foi',
#   'morto',
#   'na',
#   'maré',
#   'via',
#   'caveirão',
#   'aéreo',
#   'tem',
#   'a',
#   'mesma',
#   'idade',
#   'que',
#   'a',
#   'minha',
#   'filha,',
#   '14',
#   'anos.',
#   'hoje',
#   'e',
#   'para',
#   'sempre',
#   'haverá',
#   'uma',
#   'mãe',
#   'que',
#   'chorará',
#   'essa',
#   'morte',
#   'até',
#   'seus',
#   'últimos',
#   'dias!!',
#   'o',
#   'estado',
#   'genocida',
#   'mata',
#   'os',
#   'filhos',
#   'e...',
#   'https://www.facebook.com/100005222851187/posts/850933921757362/',
#   '…'],
#  ['caverão',
#   'aéreo.',
#   'no',
#   'início',
#   'dos',
#   'anos',
#   '2000',
#   'perguntaram',
#   'às',
#   'crianças',
#   'das',
#   'favelas',
#   'do',
#   'que',
#   'elas',
#   'tinham',
#   'medo.',
#   'resposta:',
#   'do',
#   'caveirão.',
#   'agora',
#   'o',
#   'monstro',
#   'que',
#   'aterroriza',
#   'as',
#   'crianças',
#   'das',
#   'favelas',
#   'ganhou',
#   'asas.',
#   '#paremdenosmatar'],
#  ['caveirão',
#   'aéreo',
#   'não',
#   'é',
#   'novidade,',
#   'não',
#   'é',
#   'de',
#   'hoje,',
#   'só',
#   'a',
#   'política',
#   'do',
#   'confronto',
#   'que',
#   'é',
#   'a',
#   'mesma',
#   'de',
#   'sempre',
#   'http://g1.globo.com/fantastico/noticia/2013/05/imagens-mostram-perseguicao-e-cacada-ao-traficante-matematico.html',
#   '…'],
#  ['caveirão',
#   'aéreo,',
#   'maluco',
#   'https://twitter.com/renatasouzario/status/1009451026867539970',
#   '…'],
#  ['"nossa,',
#   'o',
#   'caveirão',
#   'aéreo',
#   '(está)',
#   'dando',
#   'muito',
#   'tiro.',
#   'meu',
#   'deus,',
#   'moro',
#   'perto',
#   'do',
#   'colégio.',
#   'as',
#   'crianças',
#   'bricavam',
#   'na',
#   'quadra',
#   'e,',
#   'quando',
#   'ouviram,',
#   'foi',
#   'muita',
#   'gritaria.',
#   'que',
#   'deus',
#   'proteja',
#   'elas",',
#   '"estava',
#   'na',
#   'ciclovia',
#   'com',
#   'minha',
#   'filha',
#   'de',
#   '10',
#   'meses.',
#   'gente,',
#   'que',
#   'absurdo,',
#   'saí',
#   'correndo',
#   'no',
#   'desespero".',
#   'https://twitter.com/jornalextra/status/1009603024803848192',
#   '…'],
#  ['o',
#   'que',
#   'aconteceu',
#   'hoje',
#   'é',
#   'só',
#   'mais',
#   'um',
#   'capítulo',
#   'do',
#   'estado',
#   'de',
#   'exceção',
#   'em',
#   'que',
#   'estamos',
#   'mergulhados.',
#   'necropolítica',
#   'com',
#   'apoio',
#   'de',
#   'caveirão',
#   'aéreo.'],
#  ['um',
#   'caveirão',
#   'aéreo.',
#   'tiros',
#   'vindo',
#   'de',
#   'um',
#   'helicóptero.',
#   'uma',
#   'criança',
#   'ferida.',
#   'um',
#   'adolescente',
#   'de',
#   '14',
#   'anos',
#   'alvejado',
#   'na',
#   'barriga.',
#   'seis',
#   'mortos.',
#   'morar',
#   'na',
#   'favela',
#   'da',
#   'maré',
#   'hoje',
#   'é',
#   'ser',
#   'tratado',
#   'como',
#   'um',
#   'inimigo',
#   'ser',
#   'abatido.',
#   'como',
#   'alvo.',
#   '#moradornãoéalvo',
#   'https://odia.ig.com.br/rio-de-janeiro/2018/06/5550763-confronto-na-mare-deixa-pelo-menos-tres-moradores-feridos-diz-ong.html#foto=1',
#   '…'],
#  ['caveirão',
#   'aéreo',
#   'é',
#   'para',
#   'matar',
#   'sem',
#   'nem',
#   'olhar',
#   'pelas',
#   'costas!',
#   'canalhas!',
#   'https://twitter.com/renatasouzario/status/1009451026867539970',
#   '…'],
#  ['o',
#   'caveirão',
#   'aéreo',
#   'tá',
#   'sobrevoando',
#   'o',
#   'complexo',
#   'da',
#   'maré',
#   'nesse',
#   'momento'],
#  ['tiros,',
#   'tiros',
#   '+',
#   'tiros,',
#   'com',
#   'caveirão',
#   'aéreo',
#   'atirando',
#   'do',
#   'alto',
#   'de',
#   'sua',
#   'arrogância',
#   'e',
#   'incapacidade',
#   'tática',
#   'na',
#   'maré...',
#   'não',
#   'é',
#   'natural,',
#   'não',
#   'podemos',
#   'achar',
#   'normal.',
#   'esse',
#   'é',
#   'o',
#   'terror',
#   'do',
#   'estado',
#   'de',
#   'insegurança',
#   'pública,',
#   'a',
#   'gente',
#   'vê',
#   'por',
#   'aqui!',
#   '#nossasvidasimportam',
#   '#favelaresiste',
#   '#caveirãonão'],
#  ['📌operação',
#   'na',
#   'maré',
#   'muito',
#   'tiro',
#   'na',
#   'vila',
#   'do',
#   'pinheiro.',
#   'caveirão',
#   'aéreo',
#   'na',
#   'área.',
#   '3',
#   'blindados',
#   'no',
#   'pinheiro,',
#   'pau',
#   'quebrando',
#   'com',
#   'força',
#   'na',
#   'operação',
#   'da',
#   'polícia',
#   'civil.',
#   'chuva',
#   'de',
#   'bala',
#   'na',
#   'mare,',
#   'salsa,',
#   'vila',
#   'do',
#   'pinheiro',
#   'e',
#   'vila',
#   'do',
#   'joão.',
#   'pau',
#   'está',
#   'quebrando,',
#   'segundo...',
#   'https://www.facebook.com/rioguerracivilurbana/videos/661290804214128/',
#   '…'],
#  ['📌operação',
#   'na',
#   'maré',
#   'muito',
#   'tiro',
#   'na',
#   'vila',
#   'do',
#   'pinheiro.',
#   'caveirão',
#   'aéreo',
#   'na',
#   'área.',
#   '3',
#   'blindados',
#   'no',
#   'pinheiro,',
#   'pau',
#   'quebrando',
#   'com',
#   'força',
#   'na',
#   'operação',
#   'da',
#   'polícia',
#   'civil.',
#   'chuva',
#   'de',
#   'bala',
#   'na',
#   'mare,',
#   'salsa,',
#   'vila',
#   'do',
#   'pinheiro',
#   'e',
#   'vila',
#   'do',
#   'joão.',
#   'pau',
#   'está',
#   'quebrando,',
#   'segundo...',
#   'https://www.facebook.com/rioguerracivilurbana/videos/661290604214148/',
#   '…'],
#  ['operação',
#   'não',
#   'acabou',
#   'pessoal.',
#   'caveirão',
#   'aéreo',
#   'tá',
#   'de',
#   'volta',
#   'e',
#   'muitos',
#   'policiais',
#   'a',
#   'pé',
#   'no',
#   'miolo',
#   'da',
#   'comunidade.',
#   'vamos',
#   'nos',
#   'comunicar!!',
#   'como',
#   'está',
#   'a',
#   'rua',
#   'em',
#   'que',
#   'você',
#   'mora?'],
#  ['muito',
#   'tiro',
#   'na',
#   'vila',
#   'do',
#   'pinheiro.',
#   'caveirão',
#   'aéreo',
#   'na',
#   'área',
#   'largando',
#   'o',
#   'aço.',
#   'como',
#   'estamos',
#   'pessoal?',
#   'muito',
#   'cuidado.'],
#  ['moradores',
#   'fazem',
#   'alertas',
#   'nas',
#   'redes',
#   'sociais,',
#   'denunciando',
#   'que',
#   'o',
#   'caveirão',
#   'aéreo',
#   'estava',
#   'sobrevoando',
#   'baixo',
#   'na',
#   'região',
#   'e',
#   'atirando',
#   'em',
#   'direção',
#   'a',
#   'localidade.',
#   'o',
#   'clima',
#   'segue',
#   'tenso.',
#   'http://www.anf.org.br/apos-morte-de-inspetor-moradores-de-acari-sofrem-com-mais-um-dia-de-operacao/',
#   '…'],
#  ['moradores',
#   'fazem',
#   'alertas',
#   'nas',
#   'redes',
#   'sociais,',
#   'denunciando',
#   'que',
#   'o',
#   'caveirão',
#   'aéreo',
#   'estava',
#   'sobrevoando',
#   'baixo',
#   'na',
#   'região',
#   'e',
#   'atirando',
#   'em',
#   'direção',
#   'a',
#   'localidade.',
#   'o',
#   'clima',
#   'segue',
#   'tenso.',
#   'http://www.anf.org.br/35619-2/'],
#  ['caveirao', 'aéreo', 'me', 'acordou', '😑😑'],
#  ['qual', 'foi', 'do', 'caveirao', 'aéreo', 'sobrevoando', 'a', 'fvl?', '🚁'],
#  ['meu',
#   'coração',
#   'despedaça',
#   'com',
#   'essaa',
#   'notícias!',
#   'caveirao',
#   'aereo...',
#   'a',
#   'evolução',
#   'pra',
#   'isso',
#   'acontece',
#   ',',
#   'impressionante!'],
#  ['agora',
#   'é',
#   'vez',
#   'do',
#   'caveirao',
#   'aéreo.',
#   'é',
#   'hoje',
#   'o',
#   'dia...',
#   '🤦🏿\u200d♂️'],
#  ['ott-rj',
#   'informa',
#   ':',
#   'tiros',
#   'na',
#   'rocinha,',
#   'localidades',
#   'vila',
#   'verde',
#   'e',
#   'cachopa.',
#   'confronto',
#   'entre',
#   'bandidos',
#   'e',
#   'o',
#   'caveirão',
#   'aéreo.',
#   'atenção',
#   'no',
#   'entorno',
#   'da',
#   'comunidade.',
#   'cuidado',
#   'na',
#   'região.',
#   '#ottrj'],
#  ['caveirão.',
#   '..',
#   'vc',
#   'da',
#   'conta',
#   'do',
#   'recado',
#   'no',
#   'jogo',
#   'aéreo'],
#  ['sol',
#   'maravilhoso',
#   'para',
#   'o',
#   'caveirao',
#   'aéreo',
#   'bombardear',
#   'vagabundo'],
#  ['ah',
#   'porque',
#   'não',
#   'tem',
#   'sentido.',
#   'todas',
#   'as',
#   'armas,',
#   'obrigatoriamente,',
#   'precisam',
#   'estar',
#   'desmuniciadas.',
#   'o',
#   'risco',
#   'do',
#   'disparo',
#   'em',
#   'uma',
#   'aeronave',
#   'pressurizada',
#   'é',
#   'altíssimo.'],
#  ['isso',
#   'é',
#   'contra',
#   'a',
#   'lei.',
#   'é',
#   'proibido',
#   'o',
#   'disparo',
#   'de',
#   'aeronave',
#   'militarizada',
#   'em',
#   'região',
#   'metropolitana'],
#  ['a',
#   'velocidade',
#   'do',
#   'vento',
#   'não',
#   'serve',
#   'pra',
#   'identificar',
#   'a',
#   'distância',
#   'de',
#   'um',
#   'disparo,',
#   'e',
#   'sim',
#   'a',
#   'velocidade',
#   'do',
#   'som',
#   'e',
#   'o',
#   'ponto',
#   'final',
#   'do',
#   'trajeto.',
#   'em',
#   'outros',
#   'termos,',
#   'o',
#   'barulho',
#   'estava',
#   'alto',
#   'de',
#   'mais',
#   'comparado',
#   'aos',
#   'outros',
#   'em',
#   'relação',
#   'a',
#   'distância',
#   'da',
#   'aeronave.'],
#  ['respondendo',
#   'a',
#   'primeira',
#   'pergunta,',
#   'fui',
#   'instrutor',
#   'de',
#   'tiro',
#   'a',
#   'longa',
#   'distância',
#   'dentro',
#   'e',
#   'fora',
#   'do',
#   'brasil',
#   'por',
#   'alguns',
#   'anos,',
#   'então',
#   'de',
#   'ouvir',
#   'um',
#   'disparo',
#   'mesmo',
#   'que',
#   'por',
#   'vídeo,',
#   'dá',
#   'pra',
#   'identificar',
#   'de',
#   'onde',
#   'veio,',
#   'e',
#   'não',
#   'foi',
#   'dessa',
#   'aeronave',
#   'nesse',
#   'momento.'],
#  ['explico:',
#   'não',
#   'tem',
#   'como',
#   'ouvir',
#   'o',
#   'som',
#   'do',
#   'disparo.',
#   'o',
#   'som',
#   'que',
#   'a',
#   'aeronave',
#   'emite',
#   'possui',
#   'uma',
#   'frequência',
#   'maior.',
#   'então',
#   'não',
#   'tem',
#   'como',
#   'ouvir.',
#   'além',
#   'disso,',
#   'disparos',
#   'feitos',
#   'de',
#   'uma',
#   'aeronave',
#   'são',
#   'feitos',
#   'com',
#   'ela',
#   'no',
#   'pairado.',
#   'nessas',
#   'operações,',
#   'ela',
#   'está',
#   'em',
#   'sobrevoo.'],
#  ['dubai:saudação',
#   'dos',
#   'bombeiros',
#   'causa',
#   'dano',
#   'a',
#   'aeronave.o',
#   'jato',
#   "d'água",
#   'acertou',
#   'a',
#   'trava',
#   'externa',
#   'da',
#   'saída',
#   'de',
#   'emergência',
#   'da',
#   'asa',
#   'que',
#   'abriu',
#   'e',
#   'provocou',
#   'o',
#   'disparo',
#   'do',
#   'escorregador',
#   'inflável,dá',
#   'pra',
#   'notar',
#   'o',
#   'caminhão',
#   'da',
#   'direita',
#   'perdido',
#   'desde',
#   'o',
#   'começo',
#   '@avioesemusicas',
#   'https://tv.uol/17nuy'],
#  ['com',
#   'todo',
#   'respeito',
#   'que',
#   'tenho',
#   'pela',
#   'democracia,',
#   'discutir',
#   'um',
#   'assunto',
#   'desses',
#   'que',
#   'no',
#   'meu',
#   'ponto',
#   'de',
#   'vista,',
#   'já',
#   'é',
#   'assunto',
#   'resolvido.',
#   'senão',
#   'vejamos,',
#   'como',
#   'um',
#   'disparo',
#   'de',
#   'arma',
#   'de',
#   'fogo',
#   'dentro',
#   'de',
#   'uma',
#   'aeronave',
#   'pode',
#   'salvar',
#   'a',
#   'vida',
#   'de',
#   'alguém?',
#   'pelo',
#   'amor',
#   'de',
#   'deus,',
#   'um',
#   'disparo,',
#   'uma',
#   'queda!'],
#  ['disparo',
#   'controlado',
#   'e',
#   'preciso',
#   'não',
#   'tem',
#   'dano',
#   'colateral,movimento',
#   'da',
#   'aeronave',
#   'tá',
#   'padrão',
#   'e',
#   'só',
#   'para',
#   'deixar',
#   'claro',
#   'a',
#   'chance',
#   'de',
#   '"bala"',
#   'perdida',
#   'num',
#   'disparo',
#   'desse',
#   '80x',
#   'menos',
#   'que',
#   'um',
#   'disparo',
#   'feito',
#   'do',
#   'solo,o',
#   'barulho',
#   'assusta',
#   'mas',
#   'o',
#   'perigo',
#   'já',
#   'está',
#   'na',
#   'comunidade',
#   'andando',
#   'normalmente!',
#   'https://twitter.com/raullsantiago/status/1103994336499433472',
#   '…'],
#  ['dúvida...',
#   'o',
#   'casos',
#   'do',
#   'mh17',
#   'que',
#   'foi',
#   'abatido',
#   'na',
#   'ucrânia.',
#   'há',
#   'risco',
#   'com',
#   'a',
#   'implementação',
#   'dos',
#   'sistemas',
#   's300',
#   'e',
#   'um',
#   'abatimento',
#   'de',
#   'avião',
#   'comercial',
#   'por',
#   'suspeita',
#   'de',
#   'ser',
#   'uma',
#   'aeronave',
#   'militar',
#   'de',
#   'um',
#   'país',
#   'inimigo?',
#   'o',
#   'sistema',
#   'age',
#   'de',
#   'forma',
#   'independente',
#   'ou',
#   'precisa',
#   'da',
#   'autorização',
#   'humana',
#   'pra',
#   'disparo?'],
#  ['pf',
#   'e',
#   'mpf:',
#   '“a',
#   'queda',
#   'da',
#   'aeronave',
#   'pode',
#   'ter',
#   'sido',
#   'causada,',
#   'isolada',
#   'ou',
#   'cumulativamente,',
#   '[...]:',
#   'colisão',
#   'com',
#   'pássaros',
#   '[...];',
#   'desorientação',
#   'espacial',
#   'por',
#   'parte',
#   'dos',
#   'pilotos;',
#   'possibilidade',
#   'de',
#   'disparo',
#   'de',
#   'compensador',
#   'de',
#   'profundor;',
#   'ou',
#   'pane/travamento',
#   'de',
#   'profundor',
#   'em',
#   'posições',
#   'extremas.”.'],
#  ['aeronave',
#   'da',
#   'globo',
#   'é',
#   'atingida',
#   'por',
#   'disparo',
#   'de',
#   'guarda-chuva',
#   'ou',
#   'furadeira.',
#   'rsrs..!!',
#   'https://www.facebook.com/100002181063455/posts/1914702105279140/',
#   '…'],
#  ['entre',
#   'as',
#   'possibilidades:',
#   'colisão',
#   'com',
#   'pássaros,',
#   'gerando',
#   'uma',
#   'atitude',
#   'radical',
#   'da',
#   'aeronave;',
#   'a',
#   'desorientação',
#   'espacial',
#   'por',
#   'parte',
#   'dos',
#   'pilotos;',
#   'a',
#   'possibilidade',
#   'de',
#   'disparo',
#   'de',
#   'compensador',
#   'de',
#   'profundor;',
#   'ou',
#   'uma',
#   'pane/travamento',
#   'de',
#   'profundor',
#   'em',
#   'posições',
#   'extremas.'],
#  ['imaginem',
#   'um',
#   'disparo',
#   'acidental',
#   'em',
#   'uma',
#   'aeronave',
#   'pressurizada,',
#   'a',
#   '10.000',
#   'm',
#   'de',
#   'altura,',
#   'é',
#   'louco.',
#   'https://twitter.com/blogolhonamira/status/980840067425030146',
#   '…'],
#  ['sabe',
#   'o',
#   'que',
#   'eu',
#   'acho',
#   'muito',
#   'interessante?',
#   'é',
#   'impossível',
#   'ouvir',
#   'o',
#   'ruído',
#   'de',
#   'um',
#   'disparo',
#   'de',
#   'uma',
#   'arma',
#   'vinda',
#   'da',
#   'aeronave.',
#   'tal',
#   'qual',
#   'é',
#   'impossível',
#   'ver',
#   'o',
#   'projetil.',
#   'e',
#   'disso',
#   'eu',
#   'entendo...',
#   ';)',
#   'hahahahahahaha'],
#  ['se',
#   'considerar',
#   'um',
#   'disparo,',
#   'à',
#   'esmo,',
#   'e',
#   'aquele',
#   'buraco',
#   'no',
#   'bico',
#   'da',
#   'aeronave',
#   'tendo',
#   'sido',
#   'causado',
#   'por',
#   'um',
#   'peixe-agulha,',
#   'fou',
#   'acidente!',
#   'o',
#   'piloto,',
#   'pescador',
#   'obssessivo,',
#   'não',
#   'viu',
#   'o',
#   'projetil',
#   'e',
#   'mergulhou',
#   'pra',
#   'pescar...',
#   'e',
#   'o',
#   'teori...no',
#   'lugar',
#   'errado,',
#   'na',
#   'hora',
#   'errada?',
#   'caso',
#   'resolvido!'],
#  ['águia', 'da', 'polícia', 'militar', 'acabou', 'pousar', 'no', 'local'],
#  ['o',
#   'águia',
#   'da',
#   'polícia',
#   'rodando',
#   'o',
#   'bairro',
#   'sosksksksksksksksk'],
#  ['capaz',
#   'da',
#   'polícia',
#   'te',
#   'revistar',
#   'e',
#   'achar',
#   'um',
#   'remédio',
#   'de',
#   'dor',
#   'de',
#   'cabeça',
#   'no',
#   'teu',
#   'bolso',
#   'amigo',
#   'kkkkkkkkkkkkkkkkk',
#   'https://twitter.com/williannetoo/status/1211060393088561153',
#   '…'],
#  ['#sp:',
#   'uma',
#   'mulher',
#   'morre',
#   'ao',
#   'ser',
#   'atropelada',
#   'por',
#   'um',
#   'ônibus',
#   'no',
#   'terminal',
#   'butantã,',
#   'na',
#   'zona',
#   'oeste',
#   'de',
#   'são',
#   'paulo.',
#   'o',
#   'acidente',
#   'aconteceu',
#   'por',
#   'volta',
#   'das',
#   '7h30.',
#   'os',
#   'bombeiros',
#   'e',
#   'o',
#   'helicóptero',
#   'águia',
#   'da',
#   'polícia',
#   'militar',
#   'foram',
#   'ao',
#   'local,',
#   'mas',
#   'a',
#   'vítima',
#   'não',
#   'resistiu',
#   'aos',
#   'ferimentos.'],
#  ['polícia',
#   'procura',
#   'suspeitos',
#   'de',
#   'matar',
#   'idosa',
#   'na',
#   'zona',
#   'rural',
#   'de',
#   'águia',
#   'branca',
#   '»',
#   'https://conexaocapixaba.com.br/policia-procura-suspeitos-de-matar-idosa-na-zona-rural-de-aguia-branca/',
#   '…',
#   'pic.twitter.com/yt4xirttgy'],
#  ['eu',
#   'acho',
#   'uma',
#   'falta',
#   'de',
#   'criatividade',
#   'sem',
#   'tamanho',
#   'chamar',
#   'o',
#   'helicóptero',
#   'da',
#   'polícia',
#   'de',
#   'águia,',
#   'ao',
#   'invés',
#   'de',
#   'helicop.'],
#  ['"',
#   'helicóptero',
#   'aguia',
#   '",',
#   'policia',
#   'tem',
#   'treinamento',
#   'pra',
#   'fazer',
#   'operação',
#   'de',
#   'resgate',
#   'contra',
#   'humanos',
#   'sem',
#   'abate,',
#   'acho',
#   'q',
#   'cachorros',
#   'é',
#   'um',
#   'pouco',
#   'mais',
#   'facil',
#   'po'],
#  ['sempre',
#   'venho',
#   'aqui',
#   'retweetar',
#   'os',
#   'posts',
#   'da',
#   'polícia',
#   'militar',
#   'de',
#   'são',
#   'paulo',
#   'e',
#   'hoje',
#   'chegou',
#   'a',
#   'vez',
#   'de',
#   'agradecer',
#   'pela',
#   'intervenção',
#   'da',
#   '@pmesp',
#   'junto',
#   'com',
#   'águia',
#   'apreendendo',
#   'motocicletas',
#   'que',
#   'de',
#   'autores',
#   'que',
#   'fizeram',
#   'baderna',
#   'a',
#   'noite',
#   'inteira',
#   'aqui',
#   'em',
#   'barueri',
#   'na',
#   'rua',
#   'barueri,',
#   'parabéns',
#   'a',
#   'corporação',
#   'pic.twitter.com/6vwuyutw42'],
#  ['e',
#   'a',
#   'águia',
#   'da',
#   'polícia',
#   'que',
#   'colou',
#   'aqui',
#   'na',
#   'rua',
#   'de',
#   'baixo',
#   'do',
#   'continental',
#   'kkkkkkk',
#   'seis',
#   'acha',
#   'que',
#   'a',
#   'rua',
#   'não',
#   'tá',
#   'lotado',
#   'de',
#   'curioso'],
#  ['ñ',
#   'sou',
#   'um',
#   'ávido',
#   'seguidor',
#   'do',
#   'águia',
#   'da',
#   'noite,',
#   'mas',
#   'ontem',
#   'tava',
#   'relendo',
#   'esse',
#   'gibizaço',
#   'desenhado',
#   'pelo',
#   '@goranparlov.',
#   'uma',
#   'caçada',
#   'humana',
#   'em',
#   'terreno',
#   'inóspito',
#   'no',
#   'canadá',
#   'c/',
#   'direito',
#   'a',
#   'polícia',
#   'montada',
#   'e',
#   'perseguição',
#   'de',
#   'caiaque.',
#   'é',
#   'a',
#   'minha',
#   'história',
#   'favorita',
#   'do',
#   'sr.',
#   'willer.',
#   'pic.twitter.com/d8amtzqmn0'],
#  ['fui',
#   'no',
#   'rio',
#   'hoje',
#   'e',
#   'achei',
#   'um',
#   'filhote',
#   'de',
#   'águia',
#   'mas',
#   'que',
#   'na',
#   'vdd',
#   'é',
#   'um',
#   'filhote',
#   'de',
#   'gavião',
#   'e',
#   'levei',
#   'pra',
#   'polícia',
#   'ambiental',
#   'mas',
#   'queria',
#   'mesmo',
#   'era',
#   'criar',
#   'ela',
#   'em',
#   'casa'],
#  ['a',
#   'polícia',
#   'rodoviária',
#   'federal',
#   'informa',
#   'que',
#   'o',
#   'segundo',
#   'acidente',
#   'do',
#   'km',
#   '79',
#   'da',
#   'rodovia',
#   'fernão',
#   'dias',
#   'envolve',
#   'dois',
#   'carros',
#   'e',
#   'um',
#   'ônibus.',
#   'ainda',
#   'de',
#   'acordo',
#   'com',
#   'a',
#   'prf,',
#   'uma',
#   'criança',
#   'está',
#   'gravemente',
#   'ferida',
#   'e',
#   'será',
#   'socorrida',
#   'pelo',
#   'helicóptero',
#   'águia.'],
#  ['mais',
#   'um',
#   'dia',
#   'normal',
#   'no',
#   'bongue',
#   'com',
#   'a',
#   'aguia',
#   'da',
#   'policia',
#   'passando',
#   'aqui',
#   'em',
#   'cima'],
#  ['e',
#   'que',
#   'a',
#   'polícia',
#   'não',
#   'tenha',
#   'instaurado',
#   'nenhum',
#   'inquérito',
#   'mas',
#   'o',
#   'mp',
#   'do',
#   'rio',
#   'insiste',
#   'em',
#   '"desmantelar',
#   'a',
#   'quadrilha".',
#   'ou',
#   'o',
#   'delegado',
#   'que',
#   'conduziu',
#   'as',
#   'investigações',
#   'é',
#   'incompetente',
#   'e',
#   'o',
#   'procurador',
#   'tem',
#   'olhos',
#   'de',
#   'águia,',
#   'ou',
#   'quer',
#   'mesmo',
#   'é',
#   'afetar',
#   'bolsonaro.'],
#  ['toda',
#   'a',
#   'gente',
#   'percebe.',
#   'estado',
#   'corrupto,',
#   'muitas',
#   'mãos',
#   'untadas.',
#   'só',
#   'me',
#   'surpreende',
#   'a',
#   'polícia',
#   'e',
#   'os',
#   'juízes',
#   'não',
#   'aparecerem',
#   'de',
#   'águia',
#   'ao',
#   'peito',
#   'nas',
#   'suas',
#   'funções.',
#   'porque',
#   'os',
#   'ministros',
#   'até',
#   'despacham',
#   'o',
#   'governo',
#   'do',
#   'país',
#   'para',
#   'ir',
#   'ver',
#   'o',
#   'carnide',
#   'jogar.',
#   'https://twitter.com/atguerreiro/status/1207672153686052867',
#   '…'],
#  ['26.bpm.pmma',
#   '*polícia',
#   'militar',
#   'do',
#   'maranhão*',
#   '*c.',
#   'p.',
#   'i-c',
#   'p',
#   'a-i/3*',
#   '*26°bpm-açailândia*',
#   '*operação',
#   'comboio*',
#   '*data*:',
#   '17/12/2019',
#   '*bairros',
#   'vila',
#   'bom',
#   'jardim',
#   ',',
#   'capelosa',
#   ',',
#   'centro',
#   '*guarnição*',
#   'força',
#   'tática',
#   ',',
#   'esquadrão',
#   'águia',
#   ',...',
#   'https://www.facebook.com/100005169705355/posts/1374988379350139/',
#   '…'],
#  ['polícia',
#   'procura',
#   'suspeitos',
#   'de',
#   'latrocínio',
#   'contra',
#   'idosa',
#   'na',
#   'zona',
#   'rural',
#   'de',
#   'águia',
#   'branca',
#   'https://conexaocapixaba.com.br/policia-procura-suspeitos-de-latrocinio-contra-idosa-na-zona-rural-de-aguia-branca/',
#   '…',
#   'pic.twitter.com/t54ibmfljd'],
#  ['essa',
#   'novela',
#   'me',
#   'da',
#   'uma',
#   'águia',
#   ',ainda',
#   'bem',
#   'que',
#   'ela',
#   'chamou',
#   'a',
#   'polícia',
#   'todas',
#   'mulheres',
#   'poderiam',
#   'ter',
#   'essa',
#   'coragem',
#   'quem',
#   'sofre',
#   'por',
#   'violência',
#   'doméstica'],
#  ['👮',
#   'policiais',
#   'militares',
#   'do',
#   '43°',
#   'batalhão',
#   'de',
#   'polícia',
#   'militar',
#   'metropolitano',
#   '(bpm/m)',
#   'promoveram',
#   'a',
#   'ação',
#   '"natal',
#   'solidário"',
#   '🎅',
#   'para',
#   '200',
#   'crianças',
#   'carentes',
#   '👦👧',
#   'na',
#   'sede',
#   'da',
#   'companhia,',
#   'no',
#   'bairro',
#   'da',
#   'águia',
#   'fria,',
#   'na',
#   'capital',
#   'paulista.',
#   'veja',
#   'como',
#   'foi',
#   '👉',
#   'https://buff.ly/2epcjag',
#   '#natalsolidário',
#   'pic.twitter.com/9syovzycdw'],
#  ['poooorraaaa',
#   'pau',
#   'quebrava',
#   'ficava',
#   'com',
#   'a',
#   'nível',
#   'de',
#   'polícia',
#   '5',
#   'botando',
#   'o',
#   'águia',
#   'pra',
#   'cair',
#   'kkkkkk'],
#  ['vão',
#   'entrar',
#   'de',
#   'rapel',
#   'pelo',
#   'teto',
#   'com',
#   'apoio',
#   'do',
#   'helicóptero',
#   'águia',
#   'da',
#   'polícia',
#   'militar'],
#  ['trabalho',
#   'c/',
#   'o',
#   'helicóptero',
#   'águia',
#   'da',
#   'polícia',
#   'militar',
#   'de',
#   'são',
#   'paulo',
#   'em',
#   'bauru',
#   'e',
#   'região,',
#   'qdo',
#   'saímos',
#   'p/',
#   'atender',
#   'ocorrência,',
#   'o',
#   'qe',
#   'se',
#   'via',
#   'era',
#   'terra',
#   'invadida',
#   'pra',
#   'tdo',
#   'qto',
#   'é',
#   'lado,',
#   'barracos',
#   'em',
#   'áreas',
#   'rurais,',
#   'terrenos',
#   'urbanos',
#   'etc,',
#   'agora',
#   'no',
#   'governo',
#   'bolsonaro,',
#   'sumiram',
#   'tdos,',
#   'não',
#   'vemos',
#   'vagabundos.'],
#  ['a',
#   'rodovia',
#   'castello',
#   'branco',
#   'está',
#   'totalmente',
#   'fechada',
#   'no',
#   'sentido',
#   'do',
#   'interior,',
#   'na',
#   'altura',
#   'do',
#   'km',
#   '59,',
#   'na',
#   'região',
#   'de',
#   'são',
#   'roque.',
#   'uma',
#   'van',
#   'capotou',
#   'e',
#   'há',
#   'pelo',
#   'menos',
#   'sete',
#   'pessoas',
#   'feridas.',
#   'o',
#   'helicóptero',
#   'águia',
#   'da',
#   'polícia',
#   'militar',
#   'foi',
#   'acionado',
#   'e',
#   'está',
#   'na',
#   'pista',
#   'para',
#   'fazer',
#   'o',
#   'resgate.'],
#  ['mulher:',
#   'polícia',
#   'militar',
#   'de',
#   'sp',
#   'tem',
#   'primeira',
#   'mulher',
#   'no',
#   'comando',
#   'dos',
#   'helicópteros',
#   'águia',
#   'https://www.aopp.org.br/mulher-policia-militar-de-sp-tem-primeira-mulher-no-comando-dos-helicopteros-aguia/',
#   '…'],
#  ['vive',
#   'falando',
#   'mal',
#   'da',
#   'policia',
#   'mas',
#   'qnd',
#   'tem',
#   'a',
#   'moto',
#   'roubada',
#   'eh',
#   'o',
#   'primero',
#   'a',
#   'marca',
#   'o',
#   'esquadrao',
#   'aguia',
#   'nos',
#   'storie'],
#  ['o',
#   'que',
#   'eu',
#   'amo',
#   'das',
#   'festas',
#   'da',
#   'polícia',
#   'é',
#   'a',
#   'criatividade',
#   'nunca',
#   'vi',
#   'um',
#   'papai',
#   'noel',
#   'chegar',
#   'de',
#   'águia',
#   'kkkkkkkkk'],
#  ['mulher:',
#   'polícia',
#   'militar',
#   'de',
#   'sp',
#   'tem',
#   'primeira',
#   'mulher',
#   'no',
#   'comando',
#   'dos',
#   'helicópteros',
#   'águia',
#   'https://www.aopp.org.br/mulher-policia-militar-de-sp-tem-primeira-mulher-no-comando-dos-helicopteros-aguia/',
#   '…'],
#  ['fui',
#   'interceptado',
#   'rsrsr,',
#   '@pmesp',
#   '@grpaesp',
#   'grpae',
#   'polícia',
#   'militar',
#   'do',
#   'estado',
#   'de',
#   'são',
#   'paulo',
#   'pp-eid',
#   'águia',
#   '1',
#   'helibrás',
#   'hb-350ba',
#   'esquilo.',
#   'são',
#   'roque',
#   'sp',
#   '06/12/2019.',
#   'câmera:',
#   'canon',
#   'sx60hs',
#   '#grpae',
#   '#águia1',
#   '#helibras',
#   '#políciamilitardoestadodesãopaulo',
#   '#sbjh',
#   '#ppeid',
#   'pic.twitter.com/waygvotqkm'],
#  ['mulher:',
#   'polícia',
#   'militar',
#   'de',
#   'sp',
#   'tem',
#   'primeira',
#   'mulher',
#   'no',
#   'comando',
#   'dos',
#   'helicópteros',
#   'águia',
#   'https://www.aopp.org.br/mulher-policia-militar-de-sp-tem-primeira-mulher-no-comando-dos-helicopteros-aguia/',
#   '…'],
#  ['mulher:',
#   'polícia',
#   'militar',
#   'de',
#   'sp',
#   'tem',
#   'primeira',
#   'mulher',
#   'no',
#   'comando',
#   'dos',
#   'helicópteros',
#   'águia',
#   'https://www.aopp.org.br/mulher-policia-militar-de-sp-tem-primeira-mulher-no-comando-dos-helicopteros-aguia/',
#   '…'],
#  ['mulher:',
#   'polícia',
#   'militar',
#   'de',
#   'sp',
#   'tem',
#   'primeira',
#   'mulher',
#   'no',
#   'comando',
#   'dos',
#   'helicópteros',
#   'águia',
#   'https://www.aopp.org.br/mulher-policia-militar-de-sp-tem-primeira-mulher-no-comando-dos-helicopteros-aguia/',
#   '…'],
#  ['mulher:',
#   'polícia',
#   'militar',
#   'de',
#   'sp',
#   'tem',
#   'primeira',
#   'mulher',
#   'no',
#   'comando',
#   'dos',
#   'helicópteros',
#   'águia',
#   '-',
#   'aopp',
#   'são',
#   'paulo',
#   'https://www.aopp.org.br/mulher-policia-militar-de-sp-tem-primeira-mulher-no-comando-dos-helicopteros-aguia/',
#   '…'],
#  ['a',
#   'informação',
#   'inicial',
#   'é',
#   'de',
#   'que',
#   'essa',
#   'perseguição',
#   'começou',
#   'no',
#   'porto',
#   'de',
#   'santos',
#   'e',
#   'durou',
#   'até',
#   'a',
#   'interligação',
#   'de',
#   'planalto',
#   'do',
#   'sistema',
#   'anchieta-imigrantes.',
#   'a',
#   'polícia',
#   'e',
#   'o',
#   'helicóptero',
#   'águia',
#   'de',
#   'santos',
#   'seguiam',
#   'um',
#   'caminhão',
#   'de',
#   'pequeno',
#   'porte.'],
#  ['hoje',
#   'foi',
#   'dia',
#   'de',
#   'conhecer',
#   'o',
#   'águia,',
#   'achei',
#   'incrível',
#   'a',
# ...
#   '(que',
#   'recebe',
#   'diariamente',
#   'tiros',
#   'de',
#   'fuzil',
#   'de',
#   'helicóptero)',
#   'votou',
#   'nele.',
#   'subsidiariamente,',
#   '"gente',
#   'de',
#   'bem"',
#   'decadente',
#   'da',
#   'classe',
#   'media',
#   'carioca.'],
#  ['sugerem',
#   'a',
#   'suspensão',
#   'de',
#   'operações',
#   'policias',
#   'de',
#   'busca',
#   'e',
#   'apreensão',
#   'durante',
#   'a',
#   'noite',
#   'e',
#   'a',
#   'proibição',
#   'do',
#   'disparo',
#   'de',
#   'tiros',
#   'a',
#   'partir',
#   'de',
#   'helicóptero',
#   'policial.',
#   'de',
#   'acordo',
#   'com',
#   'o',
#   'instituto',
#   'de',
#   'segurança',
#   'pública',
#   '@isp,',
#   'nos',
#   'últimos',
#   'oito',
#   'meses,',
#   '1.249',
#   'pessoas',
#   'foram',
#   'mortas',
#   'durante',
#   'ações',
#   'policiais.'],
#  ['entre',
#   'elas',
#   'a',
#   'suspensão',
#   'de',
#   'operações',
#   'policias',
#   'de',
#   'busca',
#   'e',
#   'apreensão',
#   'durante',
#   'a',
#   'noite',
#   'e',
#   'a',
#   'proibição',
#   'do',
#   'disparo',
#   'de',
#   'tiros',
#   'a',
#   'partir',
#   'de',
#   'helicóptero',
#   'policial.'],
#  ['“não',
#   'pode',
#   'haver',
#   '#operaçõespoliciais',
#   'próximo',
#   'das',
#   'escolas.',
#   'temos',
#   'que',
#   'ter',
#   'uma',
#   'lei',
#   'sobre',
#   'isso.',
#   'já',
#   'passou',
#   'da',
#   'hora.',
#   'tiro',
#   'de',
#   'helicóptero',
#   'não',
#   'pode',
#   'nem',
#   'na',
#   'guerra',
#   'no',
#   '#iraque.',
#   'aqui',
#   'no',
#   '#rio',
#   'os',
#   '#helicóptero',
#   'atiram',
#   'nas',
#   'escolas”',
#   'gabriel',
#   'siqueira',
#   '/',
#   '@bps_nacional'],
#  ['alguém',
#   'da',
#   'um',
#   'tiro',
#   'nesse',
#   'helicóptero,',
#   'não',
#   'aguento',
#   'mais',
#   'esse',
#   'barulho'],
#  ['sonhei',
#   'que',
#   'tava',
#   'na',
#   'faculdade',
#   'e',
#   'um',
#   'helicóptero',
#   'com',
#   'ciro',
#   'tava',
#   'dando',
#   'tiro',
#   'em',
#   'todo',
#   'mundo',
#   'e',
#   'acertou',
#   'meu',
#   'primo',
#   'pequeno'],
#  ['parece',
#   'que',
#   'tráfico',
#   'acontece',
#   'nos',
#   'aviões',
#   'que',
#   'dão',
#   'suporte',
#   '...e',
#   'também',
#   'em',
#   'condomínios',
#   'de',
#   'luxo',
#   'e',
#   'em',
#   'bairros',
#   'nobres...chega',
#   'até',
#   'em',
#   'reuniãozinha',
#   'em',
#   'casas',
#   'de',
#   'luxo',
#   'de',
#   'enteados',
#   'de',
#   'políticos,mas',
#   'tiros',
#   'de',
#   'helicóptero',
#   'só',
#   'na',
#   'favela...'],
#  ['caralho',
#   'velho',
#   'a',
#   'desgraça',
#   'do',
#   'helicóptero',
#   'da',
#   'pm',
#   'acabou',
#   'de',
#   'largar',
#   'um',
#   'tiro',
#   'na',
#   'porta',
#   'da',
#   'minha',
#   'casa',
#   'e',
#   'não',
#   'tinha',
#   'exatamente',
#   'ninguém',
#   'na',
#   'rua',
#   'vcs',
#   'estão',
#   'entendo?',
#   'na',
#   'frente',
#   'daqui',
#   'de',
#   'casa!',
#   'quanto',
#   'não',
#   'faltou',
#   'pra',
#   'ter',
#   'me',
#   'acertado',
#   'na',
#   'sacada',
#   'ou',
#   'sla'],
#  ['tá',
#   'voando',
#   'uns',
#   'helicóptero',
#   'aq',
#   'bem',
#   'baixinho',
#   'vou',
#   'colocar',
#   'a',
#   'cabeça',
#   'na',
#   'janela',
#   'vai',
#   'q',
#   'dou',
#   'sorte',
#   'e',
#   'levo',
#   'um',
#   'tiro'],
#  ['o',
#   'helicóptero',
#   'utilizado',
#   'como',
#   'plataforma',
#   'de',
#   'tiros',
#   'é',
#   'uma',
#   'atentado',
#   'contra',
#   'a',
#   'população',
#   'de',
#   'favelas.',
#   'witzel',
#   'é',
#   'genocida!',
#   '#paremdenosmatar'],
#  ['o',
#   'helicóptero',
#   'utilizado',
#   'como',
#   'plataforma',
#   'de',
#   'tiros',
#   'é',
#   'uma',
#   'atentado',
#   'contra',
#   'a',
#   'população',
#   'de',
#   'favelas.',
#   'witzel',
#   'é',
#   'genocida!',
#   '#paremdenosmatar'],
#  ['"polícia',
#   'descobre',
#   'ponto',
#   'de',
#   'distribuição',
#   'de',
#   'drogas',
#   'em',
#   'bairro',
#   'nobre',
#   'de',
#   'sp".',
#   'na',
#   'ação',
#   'não',
#   'foi',
#   'disparado',
#   'nenhum',
#   'tiro.',
#   'porque',
#   'na',
#   'favela',
#   'tem',
#   'helicóptero',
#   'e',
#   'tanto',
#   'tiro?',
#   '#paremdenosmatar'],
#  ['"polícia',
#   'descobre',
#   'ponto',
#   'de',
#   'distribuição',
#   'de',
#   'drogas',
#   'em',
#   'bairro',
#   'nobre',
#   'de',
#   'sp".',
#   'na',
#   'ação',
#   'não',
#   'foi',
#   'disparado',
#   'nenhum',
#   'tiro.',
#   'porque',
#   'na',
#   'favela',
#   'tem',
#   'helicóptero',
#   'e',
#   'tanto',
#   'tiro?',
#   '#paremdenosmatar'],
#  ['estavam', 'dando', 'tiro', 'no', 'helicóptero.', 'ela', 'assustou.'],
#  ['confirmado,',
#   'teve',
#   'tiro',
#   'e',
#   'agora',
#   'tem',
#   'helicóptero',
#   'kkkkkkkkkk',
#   'rindo',
#   'de',
#   'medo'],
#  ['tá',
#   'rolando',
#   'um',
#   'bocado',
#   'de',
#   'tiro',
#   'véi,',
#   'e',
#   'o',
#   'helicóptero',
#   'tá',
#   'rodando'],
#  ['infelizmente',
#   'ou',
#   'felizmente',
#   'sim,',
#   'se',
#   'eu',
#   'tiro',
#   'o',
#   'óculos',
#   'nao',
#   'enxergo',
#   'nem',
#   'um',
#   'helicóptero',
#   'no',
#   'ceu',
#   'pqp'],
#  ['terçou',
#   'escutando',
#   'tiros',
#   'da',
#   'favela',
#   'e',
#   'helicóptero',
#   'que',
#   'não',
#   'me',
#   'deixa',
#   'nem',
#   'escutar',
#   'um',
#   'vídeo'],
#  ['eu',
#   'e',
#   'o',
#   'meu',
#   'tio',
#   'pé',
#   'bolado',
#   'no',
#   'call',
#   'of',
#   'duty',
#   'papo',
#   'de',
#   'drone',
#   'da',
#   'tiro',
#   'e',
#   'o',
#   'helicóptero',
#   'e',
#   'os',
#   'crlh'],
#  ['até',
#   'em',
#   'cima,',
#   'de',
#   'onde',
#   'agora',
#   'as',
#   'escolas',
#   'vem',
#   'recebendo',
#   'tiros',
#   'de',
#   'helicóptero'],
#  ['exército',
#   'brasileiro',
#   'recebe',
#   '25ª',
#   'unidade',
#   'do',
#   'helicóptero',
#   'fennec',
#   'modernizado',
#   'e',
#   'pronto',
#   'para',
#   'uso',
#   '(foto):',
#   'https://br.sputniknews.com/defesa/2019101414635871-exercito-brasileiro-recebe-25-unidade-do-helicoptero-fennec-modernizado-e-pronto-para-uso-foto/',
#   '…',
#   'via',
#   '@sputnik_brasil---um',
#   'tiro',
#   'de',
#   'chumbinho',
#   'derruba',
#   'isto.'],
#  ['assistir',
#   'tropa',
#   'de',
#   'elite',
#   '2',
#   'de',
#   '2010',
#   'é',
#   'ver',
#   'a',
#   'situação',
#   'do',
#   'rio',
#   'de',
#   'janeiro',
#   'em',
#   '2019,',
#   'a',
#   'cena',
#   'em',
#   'que',
#   'o',
#   'helicóptero',
#   'do',
#   'bopi',
#   'chega',
#   'na',
#   'favela',
#   'e',
#   'uns',
#   'meninos',
#   'jogando',
#   'futebol',
#   'se',
#   'deitando',
#   'do',
#   'chão',
#   'por',
#   'causa',
#   'da',
#   'força',
#   'de',
#   'tiros,',
#   'sem',
#   'falar',
#   'que',
#   'a',
#   'polícia',
#   'faz',
#   'parte',
#   'das',
#   'milícias',
#   'do',
#   'rj.'],
#  ['por',
#   'que',
#   'a',
#   'polícia',
#   'entra',
#   'na',
#   'favela',
#   'e',
#   'mata',
#   'as',
#   'pessoas,',
#   'mas',
#   'quando',
#   'entra',
#   'num',
#   'condomínio',
#   'de',
#   'luxo',
#   'não',
#   'dá',
#   'um',
#   'tiro',
#   'sequer?',
#   'por',
#   'que',
#   'o',
#   'helicóptero',
#   'sobrevoa',
#   'a',
#   'favela',
#   'disparando',
#   'tiros',
#   'e',
#   'num',
#   'condomínio',
#   'de',
#   'luxo',
#   'onde',
#   'foram',
#   'encontrados',
#   '117',
#   'fuzis',
#   'não',
#   'teve',
#   'helicóptero?',
#   'pq',
#   'a',
#   'policia',
#   'é',
#   'racista?'],
#  ['ótimo',
#   'trabalho',
#   'dos',
#   'policiais,',
#   'então',
#   'volto',
#   'a',
#   'uma',
#   'pergunta,',
#   'precisa',
#   'de',
#   'helicóptero',
#   'dando',
#   'tiro',
#   'e',
#   'jogando',
#   'granada',
#   'pra',
#   'fazer',
#   'uma',
#   'operação',
#   'bem',
#   'feita',
#   '?'],
#  ['é',
#   'revoltante',
#   'ver',
#   'um',
#   'helicóptero',
#   'em',
#   'cima',
#   'de',
#   'uma',
#   'creche',
#   'dando',
#   'tiro',
#   'pra',
#   'baixo'],
#  ['não',
#   'sei',
#   'porque,',
#   'mas',
#   'eu',
#   'tenho',
#   'pavor',
#   'de',
#   'helicóptero',
#   'muito',
#   'perto,',
#   'já',
#   'acho',
#   'que',
#   'vai',
#   'dar',
#   'tiro',
#   '🖓🖓'],
#  ['nossa',
#   'seus',
#   'sonhos',
#   'são',
#   'muito',
#   'chiques',
#   'meu',
#   'são',
#   'tipo',
#   'vruuu',
#   'dinossauro',
#   'helicóptero',
#   'velório',
#   'londres',
#   'vaso',
#   'sanitário',
#   'tiro',
#   'eu',
#   'fico',
#   'tipo',
#   'amado!?'],
#  ['a',
#   'melhor',
#   'parte',
#   'e',
#   'a',
#   'do',
#   'helicóptero',
#   'dando',
#   'tiro',
#   'kkkkkkkkkkkkk'],
#  ['se',
#   'eu',
#   'não',
#   'vou',
#   'até',
#   'praia,',
#   'trago',
#   'a',
#   'praia',
#   'até',
#   'a',
#   'mim!',
#   'peguei',
#   'um',
#   'balde',
#   'daqui',
#   'de',
#   'casa,',
#   'enchi',
#   'de',
#   'água',
#   'taquei',
#   'sal,',
#   'sal',
#   'grosso',
#   'e',
#   'to',
#   'aqui',
#   'na',
#   'minha',
#   'melhor',
#   'companhia,',
#   'pegando',
#   'uma',
#   'cor',
#   'nesse',
#   'solzinho(q',
#   'de',
#   'inho',
#   'n',
#   'tem',
#   'nd)',
#   'ao',
#   'som',
#   'de',
#   'helicóptero',
#   'sobrevoando',
#   'a',
#   'favela,',
#   'dando',
#   'tiro',
#   'p',
#   'vento'],
#  ['deu',
#   'tiro',
#   'aq',
#   'no',
#   'meu',
#   'bairro',
#   'e',
#   'agr',
#   'tem',
#   'um',
#   'helicóptero',
#   'da',
#   'polícia',
#   'rondando',
#   'a',
#   'uns',
#   '15min',
#   'sem',
#   'parar',
#   'meu',
#   'pai,',
#   'quero',
#   'ver',
#   'série',
#   'mas',
#   'com',
#   'esse',
#   'barulho',
#   'fica',
#   'difícil'],
#  ['@diegogigaton',
#   '#segredogigatonico',
#   'não',
#   'sei',
#   'nem',
#   'o',
#   'que',
#   'dizer,',
#   'eu',
#   'dei',
#   'um',
#   'tiro',
#   'dei',
#   'um',
#   'tiro',
#   'de',
#   'bazuca,',
#   'depois',
#   'dei',
#   'uns',
#   'tiros',
#   'de',
#   'sniper',
#   'e',
#   'aconteceu',
#   'isso',
#   '(não',
#   'explodiu',
#   'com',
#   'o',
#   'tiro',
#   'de',
#   'bazuca',
#   'pq',
#   'era',
#   'a',
#   'missão',
#   'que',
#   'tem',
#   'que',
#   'derrubar',
#   'o',
#   'helicóptero',
#   'do',
#   'toreno)',
#   'pic.twitter.com/og6npvy8m2'],
#  ['eu',
#   'vou',
#   'repetir',
#   'o',
#   'tweet',
#   'dele',
#   'porque',
#   'aparentemente',
#   'além',
#   'de',
#   'burro',
#   'você',
#   'e',
#   'analfabeto',
#   '(fazer',
#   'oque,',
#   'faz',
#   'parte)',
#   'por',
#   'o',
#   'acaso',
#   'traficante',
#   'tem',
#   'helicóptero..',
#   'estadual??',
#   'como',
#   'o',
#   'tiro',
#   'ia',
#   'ser',
#   'de',
#   'outra',
#   'pessoa',
#   'se',
#   'não',
#   'o',
#   'de',
#   'um',
#   'policial'],
#  ['que',
#   'passa',
#   'de',
#   'helicóptero',
#   'encima',
#   'do',
#   'morro',
#   'dando',
#   'tiro',
#   'de',
#   'cima',
#   'pra',
#   'baixo,',
#   'porque',
#   'na',
#   'favela',
#   'só',
#   'tem',
#   'bandido.',
#   'dia',
#   '12',
#   'de',
#   'outubro',
#   'de',
#   '2019,',
#   'dia',
#   'das',
#   'crianças;',
#   'ao',
#   'invés',
#   'do',
#   'morro',
#   'estar',
#   'em',
#   'festa',
#   'pelas',
#   'suas',
#   'crianças,',
#   '16',
#   'famílias',
#   'estão',
#   'chorando',
#   'as',
#   'marcas',
#   'deixadas',
#   'por',
#   'wilson',
#   'witzel',
#   '+'],
#  ['apreenderam',
#   '116',
#   'fuzis',
#   'na',
#   'casa',
#   'do',
#   'amigo',
#   'do',
#   'bolsonaro',
#   'sem',
#   'helicóptero,',
#   'sem',
#   'matar',
#   'ninguém',
#   'e',
#   'sem',
#   'dar',
#   'um',
#   'tiro.'],
#  ['descobriu',
#   'sem',
#   'pm',
#   'atirando',
#   'pra',
#   'todo',
#   'lado?',
#   'sem',
#   'helicóptero',
#   'sobrevoando,',
#   'dando',
#   'tiro',
#   'aleatoriamente?',
#   'sem',
#   'pessoas',
#   'correndo',
#   'pra',
#   'todo',
#   'lado,',
#   'se',
#   'jogando',
#   'no',
#   'chão?',
#   'sem',
#   'nenhuma',
#   'bala',
#   'perdida?',
#   'que',
#   'eficácia',
#   'seletiva.',
#   'https://twitter.com/folha/status/1182660131257016321',
#   '…'],
#  ['correção:',
#   'trafico',
#   'de',
#   'drogas',
#   'é',
#   'o',
#   'termo',
#   'correto...como',
#   'vcs',
#   'falam',
#   'das',
#   'favelas!',
#   'a',
#   'pergunta',
#   'que',
#   'não',
#   'quer',
#   'calar',
#   'é',
#   ':',
#   'rolou',
#   'tiro',
#   'de',
#   'fuzil',
#   'de',
#   'cima',
#   'do',
#   'helicóptero',
#   'em',
#   'meio',
#   'a',
#   'esses',
#   'prédios',
#   'com',
#   'snipers',
#   'e',
#   'muito',
#   'terror',
#   'nesses',
#   '"empreendedores"',
#   'de',
#   'classe',
#   'média?ou',
#   'foi',
#   'bem',
#   'pacífico',
#   'e',
#   'discreto?nojo!'],
#  ['faltou',
#   'dizer',
#   'que',
#   'mandou',
#   'helicóptero',
#   'dar',
#   'tiro',
#   'em',
#   'favela,',
#   'que',
#   'mais',
#   'gente',
#   'inocente',
#   'foi',
#   'baleada',
#   'e',
#   'que',
#   'mais',
#   'policiais',
#   'se',
#   'afastaram',
#   'por',
#   'licença',
#   'psiquiátrica!'],
#  ['você',
#   'quis',
#   'dizer',
#   'tráfico',
#   'de',
#   'drogas.',
#   'segundo,',
#   'teve',
#   'quantos',
#   'cpf',
#   'cancelados?',
#   'quantos',
#   'tiros?',
#   'teve',
#   'helicóptero',
#   'pra',
#   'dar',
#   'pipoco',
#   'na',
#   'cabeça?',
#   'https://twitter.com/folha/status/1182660131257016321',
#   '…'],
#  ['e',
#   'também,',
#   'bizarro',
#   'esse',
#   '"chama".',
#   'alguém',
#   'na',
#   'escola',
#   'lá',
#   'pediu',
#   '"por',
#   'favor',
#   'polícia,',
#   'traz',
#   'um',
#   'helicóptero',
#   'aqui',
#   'pra',
#   'praticar',
#   'tiro',
#   'ao',
#   'alvo',
#   'na',
#   'gente,',
#   'precisamos',
#   'muito',
#   'disso"'],
#  ['meu',
#   'tempo',
#   'de',
#   'mlk',
#   'dia',
#   'das',
#   'crianças',
#   'tinha',
#   'vários',
#   'projetos',
#   'da',
#   'prefeitura',
#   'pras',
#   'crianças',
#   'hoje',
#   'o',
#   'brinquedo',
#   'que',
#   'eles',
#   'manda',
#   'e',
#   'um',
#   'caverão',
#   'um',
#   'helicóptero',
#   'pra',
#   'dá',
#   'tiro',
#   'em',
#   'crianças',
#   'e',
#   'jovens',
#   'governo',
#   'que',
#   'ordena',
#   'o',
#   'ódio',
#   'que',
#   'usa',
#   'as',
#   'mesma',
#   'estratégia',
#   'que',
#   'nunca',
#   'deu',
#   'certo',
#   'affz',
#   'triste',
#   'por',
#   'isso',
#   '😓😓'],
#  ['isso',
#   'e',
#   'trafico',
#   'e',
#   'boca',
#   'de',
#   'fumo',
#   'aposto',
#   'que',
#   'chegaram',
#   'com',
#   'o',
#   'pe',
#   'na',
#   'porta,',
#   'sem',
#   'mandado',
#   'de',
#   'justica',
#   'em',
#   'um',
#   'helicoptero',
#   'dando',
#   'tiro',
#   'afinal',
#   'sempre',
#   'acontece',
#   'isso',
#   'ne',
#   'https://twitter.com/folha/status/1182660131257016321',
#   '…'],
#  ['imagina',
#   'o',
#   'governadore',
#   'de',
#   'sp',
#   'entrar',
#   'num',
#   'helicóptero',
#   'e',
#   'encher',
#   'de',
#   'tiro',
#   'o',
#   'condômino',
#   'pra',
#   'acabar',
#   'com',
#   'os',
#   'traficantes',
#   'em'],
#  ['imagina',
#   'o',
#   'governador',
#   'de',
#   'são',
#   'paulo',
#   'entrar',
#   'num',
#   'helicóptero',
#   'e',
#   'encher',
#   'de',
#   'tiro',
#   'o',
#   'condômino',
#   'pra',
#   'acabar',
#   'com',
#   'os',
#   'traficantes',
#   'https://twitter.com/folha/status/1182660131257016321',
#   '…'],
#  ['aqui',
#   'de',
#   'casa',
#   'deu',
#   'p',
#   'ouvir',
#   'vários',
#   'tiros',
#   'e',
#   'quase',
#   'agora',
#   'tinha',
#   'helicóptero',
#   'passando',
#   'baixinho'],
#  ['é',
#   'assim',
#   'que',
#   'a',
#   'gente',
#   'chama',
#   'biqueira',
#   'e',
#   'boca',
#   'de',
#   'fumo',
#   'agora',
#   'a',
#   'diferença',
#   'é',
#   'que',
#   'lá',
#   'não',
#   'vai',
#   'ter',
#   'helicóptero',
#   'dando',
#   'tiro',
#   'do',
#   'alto,',
#   'governador',
#   'falando',
#   'que',
#   'é',
#   'pra',
#   '"mirar',
#   'na',
#   'cabecinha"',
#   'etc',
#   'https://twitter.com/folha/status/1182660131257016321',
#   '…'],
#  ['porra',
#   'tava',
#   'quase',
#   'dando',
#   'tiro',
#   'pro',
#   'helicóptero',
#   'explodir',
#   'kkkkkkkk'],
#  ['mais',
#   'uma',
#   'vez,',
#   'tiros',
#   'próximo',
#   'ao',
#   'guanabara',
#   'de',
#   'irajá...',
#   'mais',
#   'uma',
#   'vez',
#   'o',
#   'helicóptero',
#   'sobrevoando',
#   'a',
#   'região.'],
#  ['witizel',
#   'já',
#   'sobrevoou',
#   'de',
#   'helicóptero,',
#   'dando',
#   '"tiro',
#   'na',
#   'cabecinha"?'],
#  ['aí',
#   'não',
#   'teve',
#   'helicóptero',
#   'dando',
#   'tiro',
#   'a',
#   'rodo,',
#   'não',
#   'é',
#   'mesmo?',
#   'https://twitter.com/folha/status/1182660131257016321',
#   '…'],
#  ['cadê',
#   'o',
#   'helicóptero',
#   'sobrevoando',
#   'e',
#   'dando',
#   'rajada',
#   'de',
#   'tiro',
#   'nesse',
#   'bairro',
#   'de',
#   'drogados,',
#   'hein!'],
#  ['mas',
#   'helicóptero',
#   'com',
#   'tiro',
#   'de',
#   'fuzil',
#   'a',
#   'esmo',
#   'só',
#   'existe',
#   'na',
#   'favela',
#   'https://twitter.com/folha/status/1182660131257016321',
#   '…'],
#  ['será',
#   'que',
#   'chegaram',
#   'dando',
#   'tiro',
#   'em',
#   'todo',
#   'mundo?',
#   'será',
#   'que',
#   'usaram',
#   'helicóptero',
#   'pra',
#   'dar',
#   'tiro?',
#   'será',
#   'que',
#   'mataram',
#   'alguma',
#   'criança',
#   'que',
#   'andava',
#   'pela',
#   'rua?',
#   'será',
#   'que',
#   'confundiram',
#   'um',
#   'pedestal',
#   'de',
#   'microfone',
#   'com',
#   'uma',
#   'arma?',
#   'será',
#   'que',
#   'alguma',
#   'mãe',
#   'q',
#   'mora',
#   'por',
#   'ali',
#   'vai',
#   'levantar',
#   'a',
#   'farda',
#   'do',
#   'filho',
#   'suja',
#   'de',
#   'sangue?',
#   'https://twitter.com/folha/status/1182660131257016321',
#   '…'],
#  ['mas', 'teve', 'tiro', 'de', 'helicóptero?!'],
#  ['e', 'cadê', 'o', 'helicóptero', 'dando', 'tiro', 'no', 'prédio?'],
#  ['grande',
#   'dia',
#   '👍🏻',
#   'agr',
#   'as',
#   'crianças',
#   'indo',
#   'pra',
#   'escola',
#   'n',
#   'vão',
#   'levar',
#   'mais',
#   'tiro',
#   'de',
#   'helicóptero',
#   'https://twitter.com/jairbolsonaro/status/1182607716910542848',
#   '…'],
#  ['todo',
#   'dia',
#   'uma',
#   'operação,',
#   'todo',
#   'dia',
#   'uma',
#   'dona',
#   'de',
#   'casa',
#   'tendo',
#   'seus',
#   'direitos',
#   'violados,',
#   'todo',
#   'dia',
#   'uma',
#   'tragédia',
#   'anunciada...',
#   'somos',
#   'todos',
#   'iguais?',
#   'aonde',
#   'cara?',
#   'aonde?',
#   'uma',
#   'criança',
#   'não',
#   'consegue',
#   'estudar',
#   'pq',
#   'o',
#   'helicóptero',
#   'tá',
#   'dando',
#   'tiro',
#   'pra',
#   'baixo...',
#   'isso',
#   'é',
#   'vida',
#   'pra',
#   'quem,',
#   'cara?'],
#  ...]

# %%
# Conta palavras mais frequentes
#palavras = list(itertools.chain(*base.tweet))

#counts_no_urls = collections.Counter(palavras)

#counts_no_urls.most_common(200)

# %%
# Mostra as mensagens mais retweetadas
#pd.set_option('display.max_colwidth', -1)

#base.nlargest(50, columns='retweets_count')[['date','tweet', 'username','retweets_count']]

# %%
#corpus = [dictionary.doc2bow(mensagens) for text in mensagens]
